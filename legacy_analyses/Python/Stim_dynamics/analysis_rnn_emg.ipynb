# %%
# import things
# %matplotlib notebook
import tensorflow as tf
from tensorflow import keras
from mpl_toolkits import mplot3d
import numpy as np
from numpy import matlib
from scipy import signal
from scipy.spatial import distance
from scipy.stats import norm
from scipy.stats import percentileofscore
import scipy.linalg as linalg

import random
import matplotlib.pyplot as plt
import os

from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics import pairwise_distances
from scipy.optimize import least_squares
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import normalize

from dPCA import dPCA

# %%
# import desired emg or velocity trajectories
predict_emg = 1
do_emg_norm = 1
go_cue_idx = 20
hold_idx = 10

# %run ./get_stim_dynamics_inputs.ipynb
x_train,y_train,x_test,y_test,degs = get_input_data(predict_emg,do_emg_norm,go_cue_idx,hold_idx)
plt.plot(y_train[1,:,:]);

# params
# %run Param_classes.ipynb
args = InitialParams()   
stim_params = StimParams()

# more verbose params
if(predict_emg):
    l2_weight = 1e-3
    activation_weight = 1e-7
    args.lambda_l = 1e-6
    dropout_rate = 0.5
    conn_prob = 1
    args.latent_shape = [30,30]
    lr = 0.0001
    n_epochs = 3000
else:
    l2_weight = 1e-3
    activation_weight = 1e-3
    args.lambda_l = 1e-5
    dropout_rate = 0.5
    conn_prob = 1
    args.latent_shape = [20,20]
    lr = 0.0001
    n_epochs = 2000
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %run ./RNN_model.ipynb

num_units = args.latent_shape[0]*args.latent_shape[1]
temp_lat = lateral_effect(args)   

input_layer = keras.Input(shape=[None,x_train.shape[-1]],batch_size=x_train.shape[0])
cell = SimpleRNN_pos_loss(num_units,activation="tanh",conn_prob = conn_prob,
                              kernel_regularizer=keras.regularizers.l2(l2_weight),activation_weight=activation_weight)
RNN_layer, state_h = keras.layers.RNN(cell,return_sequences=True,return_state=True,dynamic=True)(input_layer)                                   
dropout_layer = keras.layers.Dropout(dropout_rate)(RNN_layer)
output_layer = keras.layers.TimeDistributed(keras.layers.Dense(y_test.shape[2]))(dropout_layer)

model = tf.keras.Model(inputs=input_layer,outputs=output_layer)
stim_params.is_stim=False
optimizer = keras.optimizers.Adam(learning_rate=lr)


early_stopping_cb = keras.callbacks.EarlyStopping(patience=n_epochs/5,
                                                  restore_best_weights=True,monitor="loss")

model.compile(loss="mse",optimizer=optimizer,metrics=[keras.metrics.MeanSquaredError()])

# %%
history=model.fit(x_train,y_train,epochs=n_epochs,verbose=True,callbacks=[early_stopping_cb])
layer_outputs = [layer.output for layer in model.layers]
activation_model = keras.models.Model(inputs=model.input,outputs=layer_outputs)
# Out:
# Train on 4 samples
# Epoch 1/3000
# 4/4 [==============================] - 1s 164ms/sample - loss: 0.4707 - mean_squared_error: 0.4667
# Epoch 2/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.3205 - mean_squared_error: 0.3165
# Epoch 3/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.2670 - mean_squared_error: 0.2630
# Epoch 4/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.2455 - mean_squared_error: 0.2415
# Epoch 5/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.2358 - mean_squared_error: 0.2318
# Epoch 6/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.2323 - mean_squared_error: 0.2284
# Epoch 7/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.2254 - mean_squared_error: 0.2214
# Epoch 8/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.2212 - mean_squared_error: 0.2172
# Epoch 9/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.2114 - mean_squared_error: 0.2074
# Epoch 10/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.2079 - mean_squared_error: 0.2040
# Epoch 11/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.2058 - mean_squared_error: 0.2019
# Epoch 12/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1940 - mean_squared_error: 0.1900
# Epoch 13/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1960 - mean_squared_error: 0.1920
# Epoch 14/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1966 - mean_squared_error: 0.1927
# Epoch 15/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1910 - mean_squared_error: 0.1870
# Epoch 16/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1875 - mean_squared_error: 0.1836
# Epoch 17/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1836 - mean_squared_error: 0.1797
# Epoch 18/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1877 - mean_squared_error: 0.1838
# Epoch 19/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1797 - mean_squared_error: 0.1758
# Epoch 20/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1835 - mean_squared_error: 0.1796
# Epoch 21/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1778 - mean_squared_error: 0.1739
# Epoch 22/3000
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.1762 - mean_squared_error: 0.1723
# Epoch 23/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.1712 - mean_squared_error: 0.1673
# Epoch 24/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1688 - mean_squared_error: 0.1649
# Epoch 25/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1731 - mean_squared_error: 0.1692
# Epoch 26/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1678 - mean_squared_error: 0.1639
# Epoch 27/3000
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.1687 - mean_squared_error: 0.1648
# Epoch 28/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1677 - mean_squared_error: 0.1638
# Epoch 29/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.1636 - mean_squared_error: 0.1597
# Epoch 30/3000
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.1642 - mean_squared_error: 0.1603
# Epoch 31/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1615 - mean_squared_error: 0.1576
# Epoch 32/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.1621 - mean_squared_error: 0.1582
# Epoch 33/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1624 - mean_squared_error: 0.1585
# Epoch 34/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1604 - mean_squared_error: 0.1565
# Epoch 35/3000
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.1612 - mean_squared_error: 0.1573
# Epoch 36/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1526 - mean_squared_error: 0.1487
# Epoch 37/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1549 - mean_squared_error: 0.1510
# Epoch 38/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1542 - mean_squared_error: 0.1503
# Epoch 39/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1533 - mean_squared_error: 0.1494
# Epoch 40/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1504 - mean_squared_error: 0.1465
# Epoch 41/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1488 - mean_squared_error: 0.1449
# Epoch 42/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1481 - mean_squared_error: 0.1442
# Epoch 43/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.1481 - mean_squared_error: 0.1443
# Epoch 44/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1447 - mean_squared_error: 0.1408
# Epoch 45/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1415 - mean_squared_error: 0.1376
# Epoch 46/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1418 - mean_squared_error: 0.1380
# Epoch 47/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1452 - mean_squared_error: 0.1413
# Epoch 48/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1392 - mean_squared_error: 0.1353
# Epoch 49/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1496 - mean_squared_error: 0.1457
# Epoch 50/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1423 - mean_squared_error: 0.1384
# Epoch 51/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1408 - mean_squared_error: 0.1370
# Epoch 52/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1385 - mean_squared_error: 0.1346
# Epoch 53/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1338 - mean_squared_error: 0.1299
# Epoch 54/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1418 - mean_squared_error: 0.1380
# Epoch 55/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1369 - mean_squared_error: 0.1330
# Epoch 56/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1350 - mean_squared_error: 0.1311
# Epoch 57/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1357 - mean_squared_error: 0.1318
# Epoch 58/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.1315 - mean_squared_error: 0.1276
# Epoch 59/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1326 - mean_squared_error: 0.1287
# Epoch 60/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1372 - mean_squared_error: 0.1334
# Epoch 61/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1325 - mean_squared_error: 0.1287
# Epoch 62/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1325 - mean_squared_error: 0.1287
# Epoch 63/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1382 - mean_squared_error: 0.1343
# Epoch 64/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1326 - mean_squared_error: 0.1288
# Epoch 65/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1314 - mean_squared_error: 0.1276
# Epoch 66/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1328 - mean_squared_error: 0.1290
# Epoch 67/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1351 - mean_squared_error: 0.1313
# Epoch 68/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1251 - mean_squared_error: 0.1212
# Epoch 69/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1286 - mean_squared_error: 0.1247
# Epoch 70/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1280 - mean_squared_error: 0.1242
# Epoch 71/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1265 - mean_squared_error: 0.1226
# Epoch 72/3000
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.1298 - mean_squared_error: 0.1260
# Epoch 73/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1258 - mean_squared_error: 0.1220
# Epoch 74/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1270 - mean_squared_error: 0.1232
# Epoch 75/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1233 - mean_squared_error: 0.1195
# Epoch 76/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1256 - mean_squared_error: 0.1218
# Epoch 77/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1208 - mean_squared_error: 0.1169
# Epoch 78/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1254 - mean_squared_error: 0.1215
# Epoch 79/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.1238 - mean_squared_error: 0.1200
# Epoch 80/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1215 - mean_squared_error: 0.1177
# Epoch 81/3000
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.1245 - mean_squared_error: 0.1207
# Epoch 82/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1244 - mean_squared_error: 0.1206
# Epoch 83/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1244 - mean_squared_error: 0.1205
# Epoch 84/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1218 - mean_squared_error: 0.1180
# Epoch 85/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.1204 - mean_squared_error: 0.1166
# Epoch 86/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1184 - mean_squared_error: 0.1146
# Epoch 87/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1239 - mean_squared_error: 0.1200
# Epoch 88/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1229 - mean_squared_error: 0.1191
# Epoch 89/3000
# 4/4 [==============================] - 0s 111ms/sample - loss: 0.1194 - mean_squared_error: 0.1155
# Epoch 90/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1182 - mean_squared_error: 0.1144
# Epoch 91/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1163 - mean_squared_error: 0.1125
# Epoch 92/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1201 - mean_squared_error: 0.1163
# Epoch 93/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1173 - mean_squared_error: 0.1135
# Epoch 94/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.1188 - mean_squared_error: 0.1150
# Epoch 95/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1160 - mean_squared_error: 0.1122
# Epoch 96/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1149 - mean_squared_error: 0.1111
# Epoch 97/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1170 - mean_squared_error: 0.1132
# Epoch 98/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1146 - mean_squared_error: 0.1108
# Epoch 99/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1172 - mean_squared_error: 0.1134
# Epoch 100/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1161 - mean_squared_error: 0.1123
# Epoch 101/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1182 - mean_squared_error: 0.1144
# Epoch 102/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1134 - mean_squared_error: 0.1095
# Epoch 103/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1138 - mean_squared_error: 0.1100
# Epoch 104/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1124 - mean_squared_error: 0.1086
# Epoch 105/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.1166 - mean_squared_error: 0.1128
# Epoch 106/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1123 - mean_squared_error: 0.1085
# Epoch 107/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1152 - mean_squared_error: 0.1114
# Epoch 108/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1137 - mean_squared_error: 0.1099
# Epoch 109/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1148 - mean_squared_error: 0.1110
# Epoch 110/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1189 - mean_squared_error: 0.1151
# Epoch 111/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1144 - mean_squared_error: 0.1106
# Epoch 112/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1132 - mean_squared_error: 0.1095
# Epoch 113/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.1111 - mean_squared_error: 0.1073
# Epoch 114/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1111 - mean_squared_error: 0.1073
# Epoch 115/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1124 - mean_squared_error: 0.1086
# Epoch 116/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1100 - mean_squared_error: 0.1062
# Epoch 117/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.1113 - mean_squared_error: 0.1075
# Epoch 118/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1073 - mean_squared_error: 0.1035
# Epoch 119/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1106 - mean_squared_error: 0.1068
# Epoch 120/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1115 - mean_squared_error: 0.1077
# Epoch 121/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1103 - mean_squared_error: 0.1065
# Epoch 122/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1137 - mean_squared_error: 0.1099
# Epoch 123/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.1101 - mean_squared_error: 0.1063
# Epoch 124/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1112 - mean_squared_error: 0.1074
# Epoch 125/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1123 - mean_squared_error: 0.1085
# Epoch 126/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1073 - mean_squared_error: 0.1035
# Epoch 127/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1076 - mean_squared_error: 0.1038
# Epoch 128/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1062 - mean_squared_error: 0.1024
# Epoch 129/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1088 - mean_squared_error: 0.1050
# Epoch 130/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1059 - mean_squared_error: 0.1021
# Epoch 131/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1098 - mean_squared_error: 0.1060
# Epoch 132/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.1034 - mean_squared_error: 0.0996
# Epoch 133/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1084 - mean_squared_error: 0.1047
# Epoch 134/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1053 - mean_squared_error: 0.1015
# Epoch 135/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1063 - mean_squared_error: 0.1025
# Epoch 136/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1050 - mean_squared_error: 0.1012
# Epoch 137/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1074 - mean_squared_error: 0.1037
# Epoch 138/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1018 - mean_squared_error: 0.0980
# Epoch 139/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1069 - mean_squared_error: 0.1031
# Epoch 140/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1060 - mean_squared_error: 0.1022
# Epoch 141/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.1035 - mean_squared_error: 0.0998
# Epoch 142/3000
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.1071 - mean_squared_error: 0.1033
# Epoch 143/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1070 - mean_squared_error: 0.1032
# Epoch 144/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1052 - mean_squared_error: 0.1015
# Epoch 145/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1025 - mean_squared_error: 0.0987
# Epoch 146/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1027 - mean_squared_error: 0.0989
# Epoch 147/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1053 - mean_squared_error: 0.1016
# Epoch 148/3000
# 4/4 [==============================] - 0s 110ms/sample - loss: 0.1029 - mean_squared_error: 0.0991
# Epoch 149/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1014 - mean_squared_error: 0.0976
# Epoch 150/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1065 - mean_squared_error: 0.1027
# Epoch 151/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1056 - mean_squared_error: 0.1018
# Epoch 152/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1010 - mean_squared_error: 0.0972
# Epoch 153/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.1000 - mean_squared_error: 0.0962
# Epoch 154/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1019 - mean_squared_error: 0.0981
# Epoch 155/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1035 - mean_squared_error: 0.0998
# Epoch 156/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0978 - mean_squared_error: 0.0940
# Epoch 157/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1014 - mean_squared_error: 0.0976
# Epoch 158/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0997 - mean_squared_error: 0.0959
# Epoch 159/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1038 - mean_squared_error: 0.1001
# Epoch 160/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1017 - mean_squared_error: 0.0980
# Epoch 161/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0999 - mean_squared_error: 0.0962
# Epoch 162/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1009 - mean_squared_error: 0.0971
# Epoch 163/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1009 - mean_squared_error: 0.0971
# Epoch 164/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.1017 - mean_squared_error: 0.0979
# Epoch 165/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0991 - mean_squared_error: 0.0953
# Epoch 166/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0965 - mean_squared_error: 0.0927
# Epoch 167/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1013 - mean_squared_error: 0.0976
# Epoch 168/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1026 - mean_squared_error: 0.0988
# Epoch 169/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0983 - mean_squared_error: 0.0945
# Epoch 170/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0989 - mean_squared_error: 0.0951
# Epoch 171/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0984 - mean_squared_error: 0.0947
# Epoch 172/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.1002 - mean_squared_error: 0.0965
# Epoch 173/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0980 - mean_squared_error: 0.0942
# Epoch 174/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0989 - mean_squared_error: 0.0951
# Epoch 175/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1011 - mean_squared_error: 0.0973
# Epoch 176/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0989 - mean_squared_error: 0.0952
# Epoch 177/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0978 - mean_squared_error: 0.0940
# Epoch 178/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0966 - mean_squared_error: 0.0928
# Epoch 179/3000
# 4/4 [==============================] - 0s 110ms/sample - loss: 0.0974 - mean_squared_error: 0.0936
# Epoch 180/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1029 - mean_squared_error: 0.0992
# Epoch 181/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0952 - mean_squared_error: 0.0915
# Epoch 182/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0976 - mean_squared_error: 0.0938
# Epoch 183/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0955 - mean_squared_error: 0.0917
# Epoch 184/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0962 - mean_squared_error: 0.0924
# Epoch 185/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0977 - mean_squared_error: 0.0940
# Epoch 186/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0936 - mean_squared_error: 0.0898
# Epoch 187/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0951 - mean_squared_error: 0.0914
# Epoch 188/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0974 - mean_squared_error: 0.0937
# Epoch 189/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0933 - mean_squared_error: 0.0896
# Epoch 190/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0916 - mean_squared_error: 0.0879
# Epoch 191/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0913 - mean_squared_error: 0.0875
# Epoch 192/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0950 - mean_squared_error: 0.0912
# Epoch 193/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0933 - mean_squared_error: 0.0896
# Epoch 194/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0929 - mean_squared_error: 0.0892
# Epoch 195/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0914 - mean_squared_error: 0.0876
# Epoch 196/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0922 - mean_squared_error: 0.0885
# Epoch 197/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0961 - mean_squared_error: 0.0924
# Epoch 198/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0912 - mean_squared_error: 0.0874
# Epoch 199/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0932 - mean_squared_error: 0.0895
# Epoch 200/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0934 - mean_squared_error: 0.0896
# Epoch 201/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0902 - mean_squared_error: 0.0865
# Epoch 202/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0898 - mean_squared_error: 0.0860
# Epoch 203/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0909 - mean_squared_error: 0.0871
# Epoch 204/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0924 - mean_squared_error: 0.0887
# Epoch 205/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0906 - mean_squared_error: 0.0869
# Epoch 206/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0909 - mean_squared_error: 0.0871
# Epoch 207/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0909 - mean_squared_error: 0.0872
# Epoch 208/3000
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0911 - mean_squared_error: 0.0874
# Epoch 209/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0918 - mean_squared_error: 0.0881
# Epoch 210/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0878 - mean_squared_error: 0.0840
# Epoch 211/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0885 - mean_squared_error: 0.0848
# Epoch 212/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0893 - mean_squared_error: 0.0855
# Epoch 213/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0879 - mean_squared_error: 0.0842
# Epoch 214/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0890 - mean_squared_error: 0.0853
# Epoch 215/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0900 - mean_squared_error: 0.0863
# Epoch 216/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0909 - mean_squared_error: 0.0872
# Epoch 217/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0868 - mean_squared_error: 0.0830
# Epoch 218/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0898 - mean_squared_error: 0.0860
# Epoch 219/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0936 - mean_squared_error: 0.0898
# Epoch 220/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0873 - mean_squared_error: 0.0835
# Epoch 221/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0901 - mean_squared_error: 0.0864
# Epoch 222/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0874 - mean_squared_error: 0.0836
# Epoch 223/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0891 - mean_squared_error: 0.0854
# Epoch 224/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0896 - mean_squared_error: 0.0859
# Epoch 225/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0925 - mean_squared_error: 0.0888
# Epoch 226/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0868 - mean_squared_error: 0.0831
# Epoch 227/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0883 - mean_squared_error: 0.0845
# Epoch 228/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0874 - mean_squared_error: 0.0837
# Epoch 229/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0855 - mean_squared_error: 0.0818
# Epoch 230/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0888 - mean_squared_error: 0.0850
# Epoch 231/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0895 - mean_squared_error: 0.0858
# Epoch 232/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0906 - mean_squared_error: 0.0869
# Epoch 233/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0876 - mean_squared_error: 0.0838
# Epoch 234/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0869 - mean_squared_error: 0.0832
# Epoch 235/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0873 - mean_squared_error: 0.0836
# Epoch 236/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0865 - mean_squared_error: 0.0827
# Epoch 237/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0877 - mean_squared_error: 0.0840
# Epoch 238/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0864 - mean_squared_error: 0.0827
# Epoch 239/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0841 - mean_squared_error: 0.0804
# Epoch 240/3000
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0868 - mean_squared_error: 0.0831
# Epoch 241/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0871 - mean_squared_error: 0.0834
# Epoch 242/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0887 - mean_squared_error: 0.0850
# Epoch 243/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0856 - mean_squared_error: 0.0819
# Epoch 244/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0823 - mean_squared_error: 0.0786
# Epoch 245/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0885 - mean_squared_error: 0.0848
# Epoch 246/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0863 - mean_squared_error: 0.0826
# Epoch 247/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0857 - mean_squared_error: 0.0820
# Epoch 248/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0848 - mean_squared_error: 0.0811
# Epoch 249/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0858 - mean_squared_error: 0.0821
# Epoch 250/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0836 - mean_squared_error: 0.0799
# Epoch 251/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0849 - mean_squared_error: 0.0812
# Epoch 252/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0856 - mean_squared_error: 0.0819
# Epoch 253/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0889 - mean_squared_error: 0.0852
# Epoch 254/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0851 - mean_squared_error: 0.0814
# Epoch 255/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0834 - mean_squared_error: 0.0797
# Epoch 256/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0841 - mean_squared_error: 0.0804
# Epoch 257/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0839 - mean_squared_error: 0.0802
# Epoch 258/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0825 - mean_squared_error: 0.0788
# Epoch 259/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0847 - mean_squared_error: 0.0810
# Epoch 260/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0830 - mean_squared_error: 0.0794
# Epoch 261/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0793 - mean_squared_error: 0.0756
# Epoch 262/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0821 - mean_squared_error: 0.0784
# Epoch 263/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0845 - mean_squared_error: 0.0808
# Epoch 264/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0831 - mean_squared_error: 0.0794
# Epoch 265/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0848 - mean_squared_error: 0.0811
# Epoch 266/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0826 - mean_squared_error: 0.0789
# Epoch 267/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0830 - mean_squared_error: 0.0793
# Epoch 268/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0822 - mean_squared_error: 0.0785
# Epoch 269/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0827 - mean_squared_error: 0.0791
# Epoch 270/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0832 - mean_squared_error: 0.0795
# Epoch 271/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0822 - mean_squared_error: 0.0786
# Epoch 272/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0806 - mean_squared_error: 0.0769
# Epoch 273/3000
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0802 - mean_squared_error: 0.0765
# Epoch 274/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0813 - mean_squared_error: 0.0776
# Epoch 275/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0818 - mean_squared_error: 0.0782
# Epoch 276/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0818 - mean_squared_error: 0.0781
# Epoch 277/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0830 - mean_squared_error: 0.0794
# Epoch 278/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0825 - mean_squared_error: 0.0788
# Epoch 279/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0801 - mean_squared_error: 0.0764
# Epoch 280/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0801 - mean_squared_error: 0.0764
# Epoch 281/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0793 - mean_squared_error: 0.0756
# Epoch 282/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0817 - mean_squared_error: 0.0780
# Epoch 283/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0849 - mean_squared_error: 0.0812
# Epoch 284/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0803 - mean_squared_error: 0.0766
# Epoch 285/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0826 - mean_squared_error: 0.0789
# Epoch 286/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0812 - mean_squared_error: 0.0775
# Epoch 287/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0815 - mean_squared_error: 0.0779
# Epoch 288/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0788 - mean_squared_error: 0.0751
# Epoch 289/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0826 - mean_squared_error: 0.0789
# Epoch 290/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0809 - mean_squared_error: 0.0772
# Epoch 291/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0790 - mean_squared_error: 0.0754
# Epoch 292/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0827 - mean_squared_error: 0.0790
# Epoch 293/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0786 - mean_squared_error: 0.0749
# Epoch 294/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0789 - mean_squared_error: 0.0752
# Epoch 295/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0788 - mean_squared_error: 0.0751
# Epoch 296/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0801 - mean_squared_error: 0.0764
# Epoch 297/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0809 - mean_squared_error: 0.0772
# Epoch 298/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0802 - mean_squared_error: 0.0765
# Epoch 299/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0782 - mean_squared_error: 0.0746
# Epoch 300/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0776 - mean_squared_error: 0.0739
# Epoch 301/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0772 - mean_squared_error: 0.0736
# Epoch 302/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0794 - mean_squared_error: 0.0758
# Epoch 303/3000
# 4/4 [==============================] - 0s 110ms/sample - loss: 0.0799 - mean_squared_error: 0.0763
# Epoch 304/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0780 - mean_squared_error: 0.0743
# Epoch 305/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0773 - mean_squared_error: 0.0737
# Epoch 306/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0754 - mean_squared_error: 0.0717
# Epoch 307/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0780 - mean_squared_error: 0.0744
# Epoch 308/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0802 - mean_squared_error: 0.0765
# Epoch 309/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0794 - mean_squared_error: 0.0757
# Epoch 310/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0766 - mean_squared_error: 0.0730
# Epoch 311/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0785 - mean_squared_error: 0.0749
# Epoch 312/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0753 - mean_squared_error: 0.0717
# Epoch 313/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0773 - mean_squared_error: 0.0736
# Epoch 314/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0785 - mean_squared_error: 0.0748
# Epoch 315/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0786 - mean_squared_error: 0.0749
# Epoch 316/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0761 - mean_squared_error: 0.0725
# Epoch 317/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0751 - mean_squared_error: 0.0714
# Epoch 318/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0770 - mean_squared_error: 0.0733
# Epoch 319/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0774 - mean_squared_error: 0.0737
# Epoch 320/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0790 - mean_squared_error: 0.0753
# Epoch 321/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0774 - mean_squared_error: 0.0737
# Epoch 322/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0760 - mean_squared_error: 0.0724
# Epoch 323/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0763 - mean_squared_error: 0.0726
# Epoch 324/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0752 - mean_squared_error: 0.0716
# Epoch 325/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0779 - mean_squared_error: 0.0742
# Epoch 326/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0780 - mean_squared_error: 0.0743
# Epoch 327/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0754 - mean_squared_error: 0.0717
# Epoch 328/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0743 - mean_squared_error: 0.0707
# Epoch 329/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0780 - mean_squared_error: 0.0744
# Epoch 330/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0753 - mean_squared_error: 0.0717
# Epoch 331/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0756 - mean_squared_error: 0.0720
# Epoch 332/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0769 - mean_squared_error: 0.0732
# Epoch 333/3000
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0773 - mean_squared_error: 0.0736
# Epoch 334/3000
# 4/4 [==============================] - 0s 110ms/sample - loss: 0.0741 - mean_squared_error: 0.0705
# Epoch 335/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0744 - mean_squared_error: 0.0708
# Epoch 336/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0742 - mean_squared_error: 0.0706
# Epoch 337/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0756 - mean_squared_error: 0.0720
# Epoch 338/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0750 - mean_squared_error: 0.0713
# Epoch 339/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0744 - mean_squared_error: 0.0708
# Epoch 340/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0735 - mean_squared_error: 0.0699
# Epoch 341/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0765 - mean_squared_error: 0.0728
# Epoch 342/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0760 - mean_squared_error: 0.0723
# Epoch 343/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0755 - mean_squared_error: 0.0719
# Epoch 344/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0761 - mean_squared_error: 0.0725
# Epoch 345/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0750 - mean_squared_error: 0.0714
# Epoch 346/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0781 - mean_squared_error: 0.0744
# Epoch 347/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0749 - mean_squared_error: 0.0712
# Epoch 348/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0740 - mean_squared_error: 0.0703
# Epoch 349/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0711 - mean_squared_error: 0.0674
# Epoch 350/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0742 - mean_squared_error: 0.0706
# Epoch 351/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0731 - mean_squared_error: 0.0695
# Epoch 352/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0739 - mean_squared_error: 0.0703
# Epoch 353/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0743 - mean_squared_error: 0.0707
# Epoch 354/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0723 - mean_squared_error: 0.0686
# Epoch 355/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0776 - mean_squared_error: 0.0740
# Epoch 356/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0699 - mean_squared_error: 0.0663
# Epoch 357/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0739 - mean_squared_error: 0.0703
# Epoch 358/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0748 - mean_squared_error: 0.0712
# Epoch 359/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0739 - mean_squared_error: 0.0702
# Epoch 360/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0757 - mean_squared_error: 0.0721
# Epoch 361/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0745 - mean_squared_error: 0.0709
# Epoch 362/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0729 - mean_squared_error: 0.0692
# Epoch 363/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0748 - mean_squared_error: 0.0712
# Epoch 364/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0745 - mean_squared_error: 0.0709
# Epoch 365/3000
# 4/4 [==============================] - 0s 111ms/sample - loss: 0.0711 - mean_squared_error: 0.0675
# Epoch 366/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0783 - mean_squared_error: 0.0746
# Epoch 367/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0729 - mean_squared_error: 0.0693
# Epoch 368/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0706 - mean_squared_error: 0.0670
# Epoch 369/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0739 - mean_squared_error: 0.0702
# Epoch 370/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0726 - mean_squared_error: 0.0690
# Epoch 371/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0723 - mean_squared_error: 0.0687
# Epoch 372/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0742 - mean_squared_error: 0.0706
# Epoch 373/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0722 - mean_squared_error: 0.0686
# Epoch 374/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0733 - mean_squared_error: 0.0697
# Epoch 375/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0725 - mean_squared_error: 0.0688
# Epoch 376/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0736 - mean_squared_error: 0.0700
# Epoch 377/3000
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0716 - mean_squared_error: 0.0680
# Epoch 378/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0699 - mean_squared_error: 0.0663
# Epoch 379/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0719 - mean_squared_error: 0.0683
# Epoch 380/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0701 - mean_squared_error: 0.0665
# Epoch 381/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0694 - mean_squared_error: 0.0657
# Epoch 382/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0720 - mean_squared_error: 0.0684
# Epoch 383/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0733 - mean_squared_error: 0.0697
# Epoch 384/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0696 - mean_squared_error: 0.0659
# Epoch 385/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0727 - mean_squared_error: 0.0691
# Epoch 386/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0736 - mean_squared_error: 0.0700
# Epoch 387/3000
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0727 - mean_squared_error: 0.0691
# Epoch 388/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0686 - mean_squared_error: 0.0650
# Epoch 389/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0720 - mean_squared_error: 0.0684
# Epoch 390/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0689 - mean_squared_error: 0.0653
# Epoch 391/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0708 - mean_squared_error: 0.0671
# Epoch 392/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0723 - mean_squared_error: 0.0687
# Epoch 393/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0729 - mean_squared_error: 0.0693
# Epoch 394/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0695 - mean_squared_error: 0.0659
# Epoch 395/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0717 - mean_squared_error: 0.0681
# Epoch 396/3000
# 4/4 [==============================] - 0s 110ms/sample - loss: 0.0704 - mean_squared_error: 0.0668
# Epoch 397/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0707 - mean_squared_error: 0.0671
# Epoch 398/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0721 - mean_squared_error: 0.0685
# Epoch 399/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0677 - mean_squared_error: 0.0640
# Epoch 400/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0718 - mean_squared_error: 0.0681
# Epoch 401/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0710 - mean_squared_error: 0.0673
# Epoch 402/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0714 - mean_squared_error: 0.0678
# Epoch 403/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0706 - mean_squared_error: 0.0670
# Epoch 404/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0685 - mean_squared_error: 0.0648
# Epoch 405/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0726 - mean_squared_error: 0.0690
# Epoch 406/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0714 - mean_squared_error: 0.0678
# Epoch 407/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0696 - mean_squared_error: 0.0660
# Epoch 408/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0696 - mean_squared_error: 0.0660
# Epoch 409/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0709 - mean_squared_error: 0.0673
# Epoch 410/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0671 - mean_squared_error: 0.0635
# Epoch 411/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0729 - mean_squared_error: 0.0693
# Epoch 412/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0695 - mean_squared_error: 0.0659
# Epoch 413/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0684 - mean_squared_error: 0.0648
# Epoch 414/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0707 - mean_squared_error: 0.0671
# Epoch 415/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0717 - mean_squared_error: 0.0681
# Epoch 416/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0762 - mean_squared_error: 0.0726
# Epoch 417/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0688 - mean_squared_error: 0.0652
# Epoch 418/3000
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0697 - mean_squared_error: 0.0661
# Epoch 419/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0673 - mean_squared_error: 0.0637
# Epoch 420/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0680 - mean_squared_error: 0.0644
# Epoch 421/3000
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0693 - mean_squared_error: 0.0658
# Epoch 422/3000
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0703 - mean_squared_error: 0.0667
# Epoch 423/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0671 - mean_squared_error: 0.0635
# Epoch 424/3000
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0674 - mean_squared_error: 0.0638
# Epoch 425/3000
# ...
# Epoch 2862/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0074 - mean_squared_error: 0.0050
# Epoch 2863/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0071 - mean_squared_error: 0.0047
# Epoch 2864/3000
# 4/4 [==============================] - 0s 111ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2865/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0072 - mean_squared_error: 0.0049
# Epoch 2866/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0074 - mean_squared_error: 0.0050
# Epoch 2867/3000
# 4/4 [==============================] - 0s 119ms/sample - loss: 0.0068 - mean_squared_error: 0.0044
# Epoch 2868/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2869/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2870/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0073 - mean_squared_error: 0.0049
# Epoch 2871/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2872/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2873/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2874/3000
# 4/4 [==============================] - 0s 113ms/sample - loss: 0.0074 - mean_squared_error: 0.0051
# Epoch 2875/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0071 - mean_squared_error: 0.0047
# Epoch 2876/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2877/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0073 - mean_squared_error: 0.0049
# Epoch 2878/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2879/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0074 - mean_squared_error: 0.0050
# Epoch 2880/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2881/3000
# 4/4 [==============================] - 0s 117ms/sample - loss: 0.0069 - mean_squared_error: 0.0046
# Epoch 2882/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0076 - mean_squared_error: 0.0052
# Epoch 2883/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2884/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0071 - mean_squared_error: 0.0047
# Epoch 2885/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0077 - mean_squared_error: 0.0053
# Epoch 2886/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0073 - mean_squared_error: 0.0049
# Epoch 2887/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2888/3000
# 4/4 [==============================] - 0s 117ms/sample - loss: 0.0073 - mean_squared_error: 0.0049
# Epoch 2889/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2890/3000
# 4/4 [==============================] - 0s 112ms/sample - loss: 0.0070 - mean_squared_error: 0.0047
# Epoch 2891/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0072 - mean_squared_error: 0.0049
# Epoch 2892/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0073 - mean_squared_error: 0.0049
# Epoch 2893/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2894/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2895/3000
# 4/4 [==============================] - 0s 115ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2896/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2897/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2898/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2899/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0069 - mean_squared_error: 0.0046
# Epoch 2900/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2901/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2902/3000
# 4/4 [==============================] - 0s 116ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2903/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2904/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0069 - mean_squared_error: 0.0046
# Epoch 2905/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2906/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0068 - mean_squared_error: 0.0045
# Epoch 2907/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2908/3000
# 4/4 [==============================] - 0s 116ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2909/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0071 - mean_squared_error: 0.0047
# Epoch 2910/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0070 - mean_squared_error: 0.0047
# Epoch 2911/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0069 - mean_squared_error: 0.0046
# Epoch 2912/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0071 - mean_squared_error: 0.0047
# Epoch 2913/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2914/3000
# 4/4 [==============================] - 0s 120ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2915/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0070 - mean_squared_error: 0.0047
# Epoch 2916/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2917/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0069 - mean_squared_error: 0.0046
# Epoch 2918/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0072 - mean_squared_error: 0.0048
# Epoch 2919/3000
# 4/4 [==============================] - 0s 110ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2920/3000
# 4/4 [==============================] - 0s 117ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2921/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0068 - mean_squared_error: 0.0044
# Epoch 2922/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2923/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2924/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0070 - mean_squared_error: 0.0047
# Epoch 2925/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2926/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2927/3000
# 4/4 [==============================] - 0s 119ms/sample - loss: 0.0069 - mean_squared_error: 0.0046
# Epoch 2928/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2929/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0071 - mean_squared_error: 0.0047
# Epoch 2930/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0067 - mean_squared_error: 0.0043
# Epoch 2931/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0068 - mean_squared_error: 0.0044
# Epoch 2932/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0067 - mean_squared_error: 0.0043
# Epoch 2933/3000
# 4/4 [==============================] - 0s 115ms/sample - loss: 0.0069 - mean_squared_error: 0.0046
# Epoch 2934/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0068 - mean_squared_error: 0.0044
# Epoch 2935/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0068 - mean_squared_error: 0.0044
# Epoch 2936/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2937/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2938/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0068 - mean_squared_error: 0.0045
# Epoch 2939/3000
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0068 - mean_squared_error: 0.0045
# Epoch 2940/3000
# 4/4 [==============================] - 0s 116ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2941/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2942/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0071 - mean_squared_error: 0.0047
# Epoch 2943/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0065 - mean_squared_error: 0.0041
# Epoch 2944/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2945/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0068 - mean_squared_error: 0.0044
# Epoch 2946/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2947/3000
# 4/4 [==============================] - 0s 117ms/sample - loss: 0.0066 - mean_squared_error: 0.0042
# Epoch 2948/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2949/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0066 - mean_squared_error: 0.0042
# Epoch 2950/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2951/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2952/3000
# 4/4 [==============================] - 0s 110ms/sample - loss: 0.0067 - mean_squared_error: 0.0043
# Epoch 2953/3000
# 4/4 [==============================] - 0s 122ms/sample - loss: 0.0065 - mean_squared_error: 0.0041
# Epoch 2954/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0068 - mean_squared_error: 0.0045
# Epoch 2955/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2956/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0068 - mean_squared_error: 0.0045
# Epoch 2957/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2958/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2959/3000
# 4/4 [==============================] - 0s 117ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2960/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2961/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0071 - mean_squared_error: 0.0047
# Epoch 2962/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0069 - mean_squared_error: 0.0046
# Epoch 2963/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2964/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0069 - mean_squared_error: 0.0045
# Epoch 2965/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0067 - mean_squared_error: 0.0043
# Epoch 2966/3000
# 4/4 [==============================] - 0s 114ms/sample - loss: 0.0068 - mean_squared_error: 0.0045
# Epoch 2967/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0064 - mean_squared_error: 0.0040
# Epoch 2968/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2969/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2970/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2971/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0064 - mean_squared_error: 0.0041
# Epoch 2972/3000
# 4/4 [==============================] - 0s 116ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2973/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2974/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2975/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2976/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0068 - mean_squared_error: 0.0045
# Epoch 2977/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2978/3000
# 4/4 [==============================] - 0s 117ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2979/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2980/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0066 - mean_squared_error: 0.0042
# Epoch 2981/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2982/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2983/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2984/3000
# 4/4 [==============================] - 0s 117ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2985/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2986/3000
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0070 - mean_squared_error: 0.0046
# Epoch 2987/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0064 - mean_squared_error: 0.0041
# Epoch 2988/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2989/3000
# 4/4 [==============================] - 0s 110ms/sample - loss: 0.0063 - mean_squared_error: 0.0040
# Epoch 2990/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2991/3000
# 4/4 [==============================] - 0s 118ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2992/3000
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0063 - mean_squared_error: 0.0040
# Epoch 2993/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0065 - mean_squared_error: 0.0041
# Epoch 2994/3000
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0064 - mean_squared_error: 0.0041
# Epoch 2995/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0067 - mean_squared_error: 0.0044
# Epoch 2996/3000
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0062 - mean_squared_error: 0.0039
# Epoch 2997/3000
# 4/4 [==============================] - 0s 120ms/sample - loss: 0.0066 - mean_squared_error: 0.0043
# Epoch 2998/3000
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0065 - mean_squared_error: 0.0042
# Epoch 2999/3000
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0063 - mean_squared_error: 0.0040
# Epoch 3000/3000
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0065 - mean_squared_error: 0.0042

# %%
# summary plots
# %run ./RNN_analysis_functions.ipynb
# %run ./RNN_plot_functions.ipynb

# %%
color_list=['b','g','r','c','m','y','k','tab:purple']
        
go_cue_offset = [10,30]
activations = activation_model.predict(x_test)
rnn_activations = activations[1]
y_pred = activations[-1]
pd_data,depth_data = get_pds(rnn_activations,go_cue_offset[0]+go_cue_idx,go_cue_offset[1]+go_cue_idx)

plt.figure()
plt.subplot(2,2,1)
plt.hist(pd_data,20);
plt.subplot(2,2,2)
plt.hist(depth_data,20);
plt.subplot(2,2,3)

pd_grid = np.zeros(args.latent_shape)
pos_lis = cell.pos.astype("int")
for i in range(pd_data.shape[0]):
    pd_grid[pos_lis[i,0],pos_lis[i,1]] = pd_data[i]
plt.imshow(pd_grid)

if(predict_emg==1):
    out_idx = [12,14,16,18]
else:
    out_idx = [0,1]
    
plt.figure()
for i_out in range(len(out_idx)):
    plt.subplot(2,2,i_out+1)
    for tgt_dir_idx in range(y_test.shape[0]):
        plt.plot(np.transpose(y_pred[tgt_dir_idx,:,out_idx[i_out]]),'--',color=color_list[tgt_dir_idx]) 
        plt.plot(np.transpose(y_test[tgt_dir_idx,:,out_idx[i_out]]),'-',color=color_list[tgt_dir_idx])
        
        
rnn_activation_grid = make_activation_grid(rnn_activations,cell,args)
idx_plot = [go_cue_idx,go_cue_idx+10]
plot_activation_grids(rnn_activation_grid,idx_plot)

idx_plot = [go_cue_idx+15,go_cue_idx+20]
plot_activation_grids(rnn_activation_grid,idx_plot)
    
idx_plot = [go_cue_idx+30,go_cue_idx+35]
plot_activation_grids(rnn_activation_grid,idx_plot)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (4, 1, 30, 30)
# <img src="data:image/png;base64,..." width="640">
# (4, 1, 30, 30)
# <img src="data:image/png;base64,..." width="640">
# (4, 1, 30, 30)

# %%
# compare activation map vs shuffled maps to see if there is an organization of neurons
num_shuffles = 500
        
activations = activation_model.predict(x_test)
rnn_activations = activations[1]    
rnn_activations.shape
act_loss, shuffled_loss, act_loss_perc = evaluate_topography(rnn_activations)

plt.figure()
plt.subplot(2,1,1)
plt.plot(100-act_loss_perc) # bigger = more organization
plt.subplot(2,1,2)
plt.plot(y_pred[0,:,0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# example stim experiment

stim_params = StimParams()
args.noise_val = 0.0
stim_params.stim_pos = np.array([12,12])
stim_params.stim_dist_tau = 2
stim_params.stim_time = [go_cue_idx+10,go_cue_idx+15]

rnn_activations_stim,rnn_activations_no_stim,rnn_activation_grid_stim,rnn_activation_grid_no_stim,y_pred_stim,y_pred_no_stim = run_example_stim_exp()

rnn_activation_grid_diff = rnn_activation_grid_stim - rnn_activation_grid_no_stim

# plot activation difference
plt.figure()
subplot_idx = [6,2,4,8]
for i in range(len(subplot_idx)):
    plt.subplot(3,3,subplot_idx[i])
    plt.imshow(rnn_activation_grid_diff[i,stim_params.stim_time[0],:,:])
    plt.colorbar()
 

plt.figure()
subplot_idx = [6,2,4,8]
for i in range(len(subplot_idx)):
    plt.subplot(3,3,subplot_idx[i])
    plt.imshow(rnn_activation_grid_diff[i,stim_params.stim_time[0]+2,:,:])
    plt.colorbar()
    
plt.figure()
subplot_idx = [6,2,4,8]
for i in range(len(subplot_idx)):
    plt.subplot(3,3,subplot_idx[i])
    plt.imshow(rnn_activation_grid_diff[i,stim_params.stim_time[1]+1,:,:])
    plt.colorbar()

# plot prediction in both cases
plt.figure()
out_idx = [0,1,2,3,4,5,6,7]
color_list = ['k','r','b','g']
counter = 0
for musc_idx in out_idx:
    plt.subplot(4,2,counter+1)
    for tgt_dir_idx in range(y_pred_no_stim.shape[0]):
        plt.plot(y_pred_no_stim[tgt_dir_idx,:,musc_idx],color=color_list[tgt_dir_idx])
        plt.plot(y_pred_stim[tgt_dir_idx,:,musc_idx],linestyle='--',color=color_list[tgt_dir_idx])
        plt.axvline(stim_params.stim_time[0],linewidth=0.3)
        plt.axvline(stim_params.stim_time[0],linewidth=0.3)
        
    counter = counter + 1
    
# example neuron -- pick based on stim electrode location
rec_neuron = get_recorded_neuron(stim_params.stim_pos,cell.pos)

print(cell.pos[rec_neuron,:])
print(pd_data[rec_neuron])

plt.figure()
unit=rec_neuron
for tgt_idx in range(rnn_activations_no_stim.shape[0]):
    plt.subplot(3,3,tgt_idx+1)
    plt.plot(np.transpose(rnn_activations_no_stim[tgt_idx,:,unit]),color=color_list[tgt_idx]);
    plt.plot(np.transpose(rnn_activations_stim[tgt_idx,:,unit]),'--',color=color_list[tgt_idx]);
    plt.axvline(stim_params.stim_time[0],linewidth=0.3)
    plt.axvline(stim_params.stim_time[1],linewidth=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# [13. 13.]
# -1.0658707509678296
# <img src="data:image/png;base64,..." width="640">

# %%
# neural and emg recovery across stim amps, locations, and durations

stim_params = StimParams()
# get stim conditions
x = np.linspace(0, args.latent_shape[0], 5, dtype=np.float32)
y = np.linspace(0, args.latent_shape[1], 5, dtype=np.float32)
xv, yv = np.meshgrid(x, y)
xv = np.reshape(xv, (xv.size, 1))
yv = np.reshape(yv, (yv.size, 1))
stim_pos_test = np.hstack((xv, yv))
stim_dist_tau_test = [0.5,1,2,4,8]
stim_duration_test = [2,4,8,12]

emg_msd, rnn_msd, emg_recov, emg_stim_effect, rnn_recov, rnn_stim_effect=run_stim_exp()

# average over stim positions
emg_recov_mean = np.mean(np.mean(emg_recov,axis=3),axis=0)
emg_stim_effect_mean = np.mean(np.mean(emg_stim_effect,axis=3),axis=0)
rnn_recov_mean = np.mean(np.mean(rnn_recov,axis=3),axis=0)
rnn_stim_effect_mean = np.mean(np.mean(rnn_stim_effect,axis=3),axis=0)

# plot effect of amplitude and stim duration
plt.figure()
ax = plt.axes(projection='3d')
for i_tau in range(len(stim_dist_tau_test)):
    for i_dur in range(len(stim_duration_test)):
        ax.scatter3D(stim_dist_tau_test[i_tau],stim_duration_test[i_dur],rnn_stim_effect_mean[i_tau,i_dur],'.',color='k');
        
ax.set_xlabel("stim tau")
ax.set_ylabel("stim duration")
ax.set_zlabel("stim effect")

# plot recovery with different amplitudes and stim durations
plt.figure()
ax = plt.axes(projection='3d')
for i_tau in range(len(stim_dist_tau_test)):
    for i_dur in range(len(stim_duration_test)):
        ax.scatter3D(stim_dist_tau_test[i_tau],stim_duration_test[i_dur],rnn_recov_mean[i_tau,i_dur],'.',color='k');
        
ax.set_xlabel("stim tau")
ax.set_ylabel("stim duration")
ax.set_zlabel("recovery")

# plot example MSD for rnn and emg
plt.figure()
plt.subplot(2,1,1)
plt.plot(np.transpose(rnn_msd[:,-1,0,2,:]));
plt.subplot(2,1,2)
plt.plot(np.transpose(emg_msd[:,-1,0,2,:]));
# Out:
# 0.0
# 0.04
# 0.08
# 0.12
# 0.16
# 0.2
# 0.24
# 0.28
# 0.32
# 0.36
# 0.4
# 0.44
# 0.48
# 0.52
# 0.56
# 0.6
# 0.64
# 0.68
# 0.72
# 0.76
# 0.8
# 0.84
# 0.88
# 0.92
# 0.96
# done
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x7fda184f92e8>,
#  <matplotlib.lines.Line2D at 0x7fda184d5780>,
#  <matplotlib.lines.Line2D at 0x7fda184d58d0>,
#  <matplotlib.lines.Line2D at 0x7fda184d5a20>,
#  <matplotlib.lines.Line2D at 0x7fda184d5b70>,
#  <matplotlib.lines.Line2D at 0x7fda184d5cc0>,
#  <matplotlib.lines.Line2D at 0x7fda184d5e10>,
#  <matplotlib.lines.Line2D at 0x7fda184d5f60>,
#  <matplotlib.lines.Line2D at 0x7fda184e00f0>,
#  <matplotlib.lines.Line2D at 0x7fda184e0240>,
#  <matplotlib.lines.Line2D at 0x7fda18532400>,
#  <matplotlib.lines.Line2D at 0x7fda184e04a8>,
#  <matplotlib.lines.Line2D at 0x7fda184e05f8>,
#  <matplotlib.lines.Line2D at 0x7fda184e0748>,
#  <matplotlib.lines.Line2D at 0x7fda184e0898>,
#  <matplotlib.lines.Line2D at 0x7fda184e09e8>,
#  <matplotlib.lines.Line2D at 0x7fda184e0b38>,
#  <matplotlib.lines.Line2D at 0x7fda184e0c88>,
#  <matplotlib.lines.Line2D at 0x7fda184e0dd8>,
#  <matplotlib.lines.Line2D at 0x7fda184e0f28>,
#  <matplotlib.lines.Line2D at 0x7fda184e50b8>,
#  <matplotlib.lines.Line2D at 0x7fda184e5208>,
#  <matplotlib.lines.Line2D at 0x7fda184e5358>,
#  <matplotlib.lines.Line2D at 0x7fda184e54a8>,
#  <matplotlib.lines.Line2D at 0x7fda184e55f8>]

# %%
# dynamical analysis (PCA? and such on activations in RNN layer)
# activations is tgt_dir x time x neuron
# truncate activations from go cue to end
stim_params = StimParams()
args.noise_val = 0.0
stim_params.stim_pos = np.array([10,10])
stim_params.stim_dist_tau = 5
stim_params.stim_time = [go_cue_idx+10,go_cue_idx+15]

rnn_activations_stim,rnn_activations_no_stim,rnn_activation_grid_stim,rnn_activation_grid_no_stim,y_pred_stim,y_pred_no_stim = run_example_stim_exp()

rnn_no_stim_trunc = rnn_activations_no_stim[:,:,:]
rnn_stim_trunc = rnn_activations_stim[:,:,:]

rnn_activations_no_stim_flat = rnn_no_stim_trunc.reshape(-1,rnn_activations_no_stim.shape[-1])
rnn_activations_stim_flat = rnn_stim_trunc.reshape(-1,rnn_activations_stim.shape[-1])

pca = PCA(n_components=10)
pca.fit(rnn_activations_no_stim_flat)

rnn_pca_no_stim = pca.transform(rnn_activations_no_stim_flat)
rnn_pca_stim = pca.transform(rnn_activations_stim_flat)
rnn_pca_no_stim = rnn_pca_no_stim.reshape(len(degs),int(rnn_pca_no_stim.shape[0]/len(degs)),rnn_pca_no_stim.shape[1])
rnn_pca_stim = rnn_pca_stim.reshape(len(degs),int(rnn_pca_stim.shape[0]/len(degs)),rnn_pca_stim.shape[1])

dims = [0,1]
plt.figure()
for tgt_idx in range(rnn_pca_no_stim.shape[0]):
    plot_pca_traces(rnn_pca_no_stim,tgt_idx,dims)
    plot_pca_traces(rnn_pca_stim,tgt_idx,dims,is_stim=True)
    
plt.figure()
for tgt_idx in range(rnn_pca_no_stim.shape[0]):
    plt.subplot(3,3,tgt_idx+1)
    plot_pca_traces(rnn_pca_no_stim,tgt_idx,dims)
    plot_pca_traces(rnn_pca_stim,tgt_idx,dims,is_stim=True)

# %%
# dpca
# X = multi dimensional array. [n,t,s,d] where n is neurons, t is time, s is stimulus, d is decision
# labels = optional; list of characters to describe parameter axes ('tsd')
# n_components = Dictionary or integer; if integer use the same number of components in each marginalization,
    #otherwise every (key,value) pair refers to the number of components (value) in a marginalization (key).
stim_params = StimParams()
args.noise_val = 0.0
stim_params.stim_pos = np.array([0,0])
stim_params.stim_dist_tau = 1
stim_params.stim_time = [go_cue_idx+10,go_cue_idx+15]

rnn_activations_stim,rnn_activations_no_stim,\
    rnn_activation_grid_stim,rnn_activation_grid_no_stim,\
    y_pred_stim,y_pred_no_stim = run_example_stim_exp()
        
X_no_stim = np.transpose(rnn_activations_no_stim,(2,1,0))
X_stim = np.transpose(rnn_activations_stim,(2,1,0))

labels = 'ts'
dpca = dPCA.dPCA(labels)
dpca.protect = ['t']
Z_no_stim = dpca.fit_transform(X_no_stim)
Z_stim = dpca.transform(X_stim)

for i_dim in range(3):
    plt.figure()
    plot_dpca_traces(Z_no_stim,0,'t',i_dim)
    plot_dpca_traces(Z_stim,1,'t',i_dim)
     
dims = [0,1]
plt.figure()
for i_tgt in range(Z_stim['s'].shape[-1]):
    plt.plot(Z_no_stim['s'][dims[0],:,i_tgt],Z_no_stim['s'][dims[1],:,i_tgt])
    #plt.plot(Z_stim['s'][dims[0],:,i_tgt],Z_stim['s'][dims[1],:,i_tgt])

# %%
# Potent and Null space analysis
# get a mapping from neuron activation to muscle activation
explained_var_thresh = 0.75

# %run ./RNN_analysis_functions.ipynb

activations = activation_model.predict(x_test)
neural_act = activations[1] 
muscle_act = activations[-1]

neural_act_flat = flatten_activation_mat(neural_act)
muscle_act_flat = flatten_activation_mat(muscle_act)

# reduce dimensions -- match explained variance across muscles and neurons
neural_pca = PCA()
muscle_pca = PCA()
neural_pca.fit(neural_act_flat)
muscle_pca.fit(muscle_act_flat)

n_neural_comp = np.argwhere(np.cumsum(neural_pca.explained_variance_ratio_) >= explained_var_thresh)[0][0]
n_muscle_comp = np.argwhere(np.cumsum(muscle_pca.explained_variance_ratio_) >= explained_var_thresh)[0][0]

neural_pca = PCA(n_components=n_neural_comp)
muscle_pca = PCA(n_components=n_muscle_comp)
neural_act_low_dim = unflatten_activation_mat(neural_pca.fit_transform(neural_act_flat),neural_act)
muscle_act_low_dim = unflatten_activation_mat(muscle_pca.fit_transform(muscle_act_flat),muscle_act)

# project
null_space, potent_space = get_null_potent_space(neural_act_low_dim, muscle_act_low_dim) # neural dims, muscle dims
neural_null_proj = project_into_space(neural_act_low_dim, null_space)
neural_pot_proj = project_into_space(neural_act_low_dim, potent_space)

# stimulate and project activations into potent and null space -- do this for different amplitudes and stim locations
stim_params = StimParams()
args.noise_val = 0.0
stim_params.stim_time = [go_cue_idx+10,go_cue_idx+15]
amps_test = np.array([0.5,1,2,5,10])
# get locs test
x = np.linspace(0, args.latent_shape[0], 5, dtype=np.float32)
y = np.linspace(0, args.latent_shape[1], 5, dtype=np.float32)
xv, yv = np.meshgrid(x, y)
xv = np.reshape(xv, (xv.size, 1))
yv = np.reshape(yv, (yv.size, 1))
stim_pos_test = np.hstack((xv, yv))

null_dist = np.zeros((amps_test.shape[0],stim_pos_test.shape[0],neural_act.shape[1]))
pot_dist = np.zeros_like(null_dist)

neural_stim_null_proj_all = np.zeros((amps_test.shape[0],stim_pos_test.shape[0],\
                                      neural_act.shape[0],neural_act.shape[1],\
                                      n_neural_comp-n_muscle_comp))
neural_stim_pot_proj_all = np.zeros((amps_test.shape[0],stim_pos_test.shape[0],\
                                     neural_act.shape[0],neural_act.shape[1],\
                                      n_muscle_comp))

for i_amp in range(amps_test.shape[0]):
    for i_loc in range(stim_pos_test.shape[0]):
        stim_params.stim_pos = stim_pos_test[i_loc,:]
        stim_params.stim_dist_tau = amps_test[i_amp]


        neural_act_stim,neural_act_no_stim,\
            neural_act_grid_stim,neural_act_grid_no_stim,\
            musc_pred_stim,musc_pred_no_stim = run_example_stim_exp()

        # lower dimensionality then project stim data into spaces
        neural_act_stim_flat = flatten_activation_mat(neural_act_stim)
        neural_act_stim_low_d =  unflatten_activation_mat(neural_pca.transform(neural_act_stim_flat),neural_act_stim)

        neural_stim_null_proj = project_into_space(neural_act_stim_low_d,null_space)
        neural_stim_pot_proj = project_into_space(neural_act_stim_low_d,potent_space)

        # compute distance moved from normal trajectory during stim condition in null and potent space across time and store
        null_dist[i_amp,i_loc,:] = np.sum(np.sum(np.square(neural_stim_null_proj - neural_null_proj),axis=2),axis=0)
        pot_dist[i_amp,i_loc,:] = np.sum(np.sum(np.square(neural_stim_pot_proj - neural_pot_proj),axis=2),axis=0)
        
        # store all proj data
        neural_stim_null_proj_all[i_amp,i_loc,:,:,:] = neural_stim_null_proj
        neural_stim_pot_proj_all[i_amp,i_loc,:,:,:] = neural_stim_pot_proj

# %%
# analyze distance data -- time course (potent recovers slower than null?), 
    # magnitude post stim relative to pre stim (hump after end of stim implies planning?)

# plot dists for example site and amp
plt.figure() 
plt.plot(np.transpose(null_dist[4,12,:]),color='k');
plt.plot(np.transpose(pot_dist[4,12,:]),color='r');
plt.axvline(stim_params.stim_time[0],linewidth=0.5)
plt.axvline(stim_params.stim_time[1],linewidth=0.5)

# compare distances between null and pot across amps and sites
summed_null_dist = np.sum(null_dist,axis=2)
summed_pot_dist = np.sum(pot_dist,axis=2)
plot_space_dist(summed_null_dist,summed_pot_dist)
    
summed_null_dist = np.sum(null_dist[:,:,stim_params.stim_time[0]:stim_params.stim_time[1]],axis=2)
summed_pot_dist = np.sum(pot_dist[:,:,stim_params.stim_time[0]:stim_params.stim_time[1]],axis=2)
plot_space_dist(summed_null_dist,summed_pot_dist) 

summed_null_dist = np.sum(null_dist[:,:,stim_params.stim_time[1]+1:stim_params.stim_time[1]+5],axis=2)
summed_pot_dist = np.sum(pot_dist[:,:,stim_params.stim_time[1]+1:stim_params.stim_time[1]+5],axis=2)
plot_space_dist(summed_null_dist,summed_pot_dist)

# %%
# plot proj onto null space and proj onto potent space (on the same axis?)
plt.figure()
dim = 0;
tgt = 2;
plt.plot(neural_stim_null_proj[tgt,:,dim],neural_stim_pot_proj[tgt,:,dim])
plt.plot(neural_stim_null_proj[tgt,stim_params.stim_time[0]:stim_params.stim_time[1],dim],\
         neural_stim_pot_proj[tgt,stim_params.stim_time[0]:stim_params.stim_time[1],dim])
plt.plot(neural_stim_null_proj[tgt,0,dim],neural_stim_pot_proj[tgt,0,dim],markersize=20,marker='.')
plt.plot(neural_stim_null_proj[tgt,go_cue_idx,dim],neural_stim_pot_proj[tgt,go_cue_idx,dim],markersize=20,marker='.')
plt.plot(neural_stim_null_proj[tgt,50,dim],neural_stim_pot_proj[tgt,50,dim],markersize=20,marker='.')

# %%
tgt = 2
amp = 3
loc = 10

plt.figure()
plt.subplot(2,1,1)
plt.plot(neural_pot_proj[tgt,:,:])
plt.gca().set_prop_cycle(None)
plt.plot(neural_stim_pot_proj_all[amp,loc,tgt,:,:],linestyle='--')
plt.axvline(hold_idx,linewidth=0.5)
plt.axvline(go_cue_idx,linewidth=0.5)
plt.axvline(stim_params.stim_time[0],linewidth=0.5)
plt.axvline(stim_params.stim_time[1],linewidth=0.5)

plt.subplot(2,1,2)
plt.plot(neural_null_proj[tgt,:,:])
plt.gca().set_prop_cycle(None)
plt.plot(neural_stim_null_proj_all[amp,loc,tgt,:,:],linestyle='--')
plt.axvline(hold_idx,linewidth=0.5)
plt.axvline(go_cue_idx,linewidth=0.5)
plt.axvline(stim_params.stim_time[0],linewidth=0.5)
plt.axvline(stim_params.stim_time[1],linewidth=0.5)
