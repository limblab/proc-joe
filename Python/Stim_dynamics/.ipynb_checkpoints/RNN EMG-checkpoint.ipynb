# %%
# import things
# %matplotlib notebook
import tensorflow as tf
from tensorflow import keras
from mpl_toolkits import mplot3d
import numpy as np
from numpy import matlib
from scipy import signal
from scipy.spatial import distance
from scipy.stats import norm
from scipy.stats import percentileofscore
import random
import matplotlib.pyplot as plt
import os

from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics import pairwise_distances
from scipy.optimize import least_squares

from dPCA import dPCA

# %%
# import desired emg or velocity trajectories
predict_emg = 1
do_emg_norm = 1
go_cue_idx = 20
hold_idx = 10

# %run ./get_stim_dynamics_inputs.ipynb
x_train,y_train,x_test,y_test = get_input_data(predict_emg,do_emg_norm,go_cue_idx,hold_idx)


plt.plot(y_train[1,:,:]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# params
# %run Param_classes.ipynb
args = InitialParams()   
stim_params = StimParams()

def locmap(args):
    '''
    :return: location of each neuron
    '''
    x = np.arange(0, args.latent_shape[0], dtype=np.float32)
    y = np.arange(0, args.latent_shape[1], dtype=np.float32)
    xv, yv = np.meshgrid(x, y)
    xv = np.reshape(xv, (xv.size, 1))
    yv = np.reshape(yv, (yv.size, 1))
    return np.hstack((xv, yv))

def lateral_effect(args):
    '''
    :return: functions of lateral effect
    '''
    locations = locmap(args)
    weighted_distance_matrix = euclidean_distances(locations, locations)/args.sigma

    if args.lateral is 'mexican':
        S = (1.0-0.5*np.square(weighted_distance_matrix))*np.exp(-0.5*np.square(weighted_distance_matrix))
        return S-np.eye(len(locations))

    if args.lateral is 'rbf':
        S = np.exp(-0.5*np.square(weighted_distance_matrix))
        return S-np.eye(len(locations))
    
    print('no lateral effect is chosen')
    return np.zeros(weighted_distance_matrix.shape, dtype=np.float32)

# %%
if(predict_emg):
    l2_weight = 1e-3
    activation_weight = 1e-7
    args.lambda_l = 1e-6
    dropout_rate = 0.5
    conn_prob = 1
    args.latent_shape = [30,30]
else:
    l2_weight = 1e-3
    activation_weight = 1e-3
    args.lambda_l = 1e-5
    dropout_rate = 0.5
    conn_prob = 1
    args.latent_shape = [20,20]
    
num_units = args.latent_shape[0]*args.latent_shape[1]
temp_lat = lateral_effect(args)   

class SimpleRNN_pos_loss(keras.layers.Layer):
    def __init__(self, units, conn_prob=1, activation="tanh", kernel_regularizer=None,activation_weight=0, **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.kernel_regularizer = kernel_regularizer
        self.activation_weight = activation_weight
        self.simple_rnn_cell = keras.layers.SimpleRNNCell(units,
                                                          activation=None,kernel_initializer='glorot_uniform',
                                                          kernel_regularizer=self.kernel_regularizer,
                                                          recurrent_initializer=tf.keras.initializers.glorot_normal,
                                                          )
        
        self.activation = keras.activations.get(activation)
        self.pos = locmap(args)
        self.lateral_effect = lateral_effect(args)
        self.lateral_effect = tf.convert_to_tensor(self.lateral_effect,dtype="float32")
        self.counter = -1
        
        self.conn_prob = conn_prob
        self.conn_mat = self.get_connection_mask(units)
        
    def call(self, inputs, states):
        # apply connection mask to simple_rnn_weights and then set weights
        #weight_mat = self.simple_rnn_cell.get_weights()
        #if(len(weight_mat)>0): # apply connection
        #    weight_mat[1] = tf.multiply(self.conn_mat,weight_mat[1])
        #    self.simple_rnn_cell.set_weights(weight_mat)
            
        # run rnn cell
        outputs, self.states = self.simple_rnn_cell(inputs, states)
        
        # activation
        outputs = self.activation(outputs + np.random.random(outputs.shape)*args.noise_val-args.noise_val/2)
        
        # lateral loss
        A = tf.matmul(tf.convert_to_tensor(outputs,dtype="float32"),self.lateral_effect)
        # loss is -1*mean of diagonal elements
        lateral_loss = -1*tf.reduce_mean(tf.linalg.diag_part(A))
        self.add_loss(args.lambda_l*lateral_loss)
        
        # loss based on activations
        self.add_loss(tf.reduce_mean(outputs)*self.activation_weight)
        
        # adjust outputs based on stim
        if(stim_params.is_stim and stim_params.stim_dist_tau > 0 and self.counter >= stim_params.stim_time[0] and self.counter <=stim_params.stim_time[1]):
            # set activations around electrode to 1 with an exponential decay prob based on distance
            # get distance from stim_pos
            stim_dists = pairwise_distances(cell.pos,np.expand_dims(stim_params.stim_pos,axis=0))
            
            # turn distance into prob_act based on stim_dist_decay
            prob_act = np.exp(-1*stim_dists/stim_params.stim_dist_tau)
            # determine which cells were activated
            cell_activated = (np.argwhere(np.random.random(prob_act.shape) < prob_act))
            cell_activated = np.expand_dims(cell_activated[:,0],axis=1)
            
            # set output
            outputs=tf.transpose(outputs)
            outputs=tf.tensor_scatter_nd_update(outputs,tf.convert_to_tensor(cell_activated),tf.ones((cell_activated.shape[0],outputs.shape[1])))
            outputs=tf.transpose(outputs)
            
        self.counter = self.counter + 1
        return outputs, [outputs]

    def reset_counter(self):
        self.counter = -1
        
    def get_connection_mask(self,units):
        # produces units x units matrix where each entry is a 1 or 0 determining if cells are connected
        # diagonal must be 1
        conn_mat = np.random.random((units,units)) < self.conn_prob
        conn_mat = conn_mat.astype(np.float32)
        np.fill_diagonal(conn_mat,1.0)
        conn_mat = tf.convert_to_tensor(conn_mat)
        return conn_mat
        
input_layer = keras.Input(shape=[None,x_train.shape[-1]],batch_size=x_train.shape[0])
cell = SimpleRNN_pos_loss(num_units,activation="tanh",conn_prob = conn_prob,
                              kernel_regularizer=keras.regularizers.l2(l2_weight),activation_weight=activation_weight)
RNN_layer, state_h = keras.layers.RNN(cell,return_sequences=True,return_state=True,dynamic=True)(input_layer)                                   
dropout_layer = keras.layers.Dropout(dropout_rate)(RNN_layer)
output_layer = keras.layers.TimeDistributed(keras.layers.Dense(y_test.shape[2]))(dropout_layer)

model = tf.keras.Model(inputs=input_layer,outputs=output_layer)

# %%
root_logdir = os.path.join(os.getcwd(), "my_logs")

class CustomPrintCB(tf.keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs=None):
        if(epoch%100 == 1):
            print('Epoch {}. Loss = {}'.format(epoch,logs['loss']))

def get_run_logdir():
    import time
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir() # e.g., './my_logs/run_2019_06_07-15_15_22'
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
stim_params.is_stim=False
if(predict_emg):
    lr = 0.0001
    n_epochs = 2500
else:
    lr = 0.0001
    n_epochs = 2000
optimizer = keras.optimizers.Adam(learning_rate=lr)


early_stopping_cb = keras.callbacks.EarlyStopping(patience=n_epochs/5,
                                                  restore_best_weights=True,monitor="loss")


model.compile(loss="mse",optimizer=optimizer,metrics=[keras.metrics.MeanSquaredError()])

# %%
history=model.fit(x_train,y_train,epochs=n_epochs,verbose=True,callbacks=[early_stopping_cb])
layer_outputs = [layer.output for layer in model.layers]
activation_model = keras.models.Model(inputs=model.input,outputs=layer_outputs)
# Out:
# Train on 4 samples
# Epoch 1/2500
# 4/4 [==============================] - 1s 139ms/sample - loss: 0.3314 - mean_squared_error: 0.3275
# Epoch 2/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.2533 - mean_squared_error: 0.2494
# Epoch 3/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.2366 - mean_squared_error: 0.2327
# Epoch 4/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.2337 - mean_squared_error: 0.2298
# Epoch 5/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.2238 - mean_squared_error: 0.2199
# Epoch 6/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.2151 - mean_squared_error: 0.2112
# Epoch 7/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.2053 - mean_squared_error: 0.2014
# Epoch 8/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.2031 - mean_squared_error: 0.1993
# Epoch 9/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1999 - mean_squared_error: 0.1960
# Epoch 10/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1952 - mean_squared_error: 0.1913
# Epoch 11/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1918 - mean_squared_error: 0.1879
# Epoch 12/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.1904 - mean_squared_error: 0.1866
# Epoch 13/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1863 - mean_squared_error: 0.1824
# Epoch 14/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1828 - mean_squared_error: 0.1789
# Epoch 15/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1763 - mean_squared_error: 0.1724
# Epoch 16/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1756 - mean_squared_error: 0.1717
# Epoch 17/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1805 - mean_squared_error: 0.1766
# Epoch 18/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1722 - mean_squared_error: 0.1683
# Epoch 19/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1690 - mean_squared_error: 0.1651
# Epoch 20/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1683 - mean_squared_error: 0.1644
# Epoch 21/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1687 - mean_squared_error: 0.1649
# Epoch 22/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1624 - mean_squared_error: 0.1585
# Epoch 23/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1594 - mean_squared_error: 0.1555
# Epoch 24/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1609 - mean_squared_error: 0.1571
# Epoch 25/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1612 - mean_squared_error: 0.1574
# Epoch 26/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1575 - mean_squared_error: 0.1536
# Epoch 27/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1581 - mean_squared_error: 0.1543
# Epoch 28/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1514 - mean_squared_error: 0.1476
# Epoch 29/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1537 - mean_squared_error: 0.1499
# Epoch 30/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1509 - mean_squared_error: 0.1470
# Epoch 31/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1500 - mean_squared_error: 0.1461
# Epoch 32/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1503 - mean_squared_error: 0.1464
# Epoch 33/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1483 - mean_squared_error: 0.1445
# Epoch 34/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1493 - mean_squared_error: 0.1454
# Epoch 35/2500
# 4/4 [==============================] - 0s 84ms/sample - loss: 0.1540 - mean_squared_error: 0.1501
# Epoch 36/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1481 - mean_squared_error: 0.1442
# Epoch 37/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1477 - mean_squared_error: 0.1439
# Epoch 38/2500
# 4/4 [==============================] - 0s 85ms/sample - loss: 0.1408 - mean_squared_error: 0.1370
# Epoch 39/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1459 - mean_squared_error: 0.1421
# Epoch 40/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1405 - mean_squared_error: 0.1367
# Epoch 41/2500
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.1463 - mean_squared_error: 0.1425
# Epoch 42/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1414 - mean_squared_error: 0.1376
# Epoch 43/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1407 - mean_squared_error: 0.1368
# Epoch 44/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1403 - mean_squared_error: 0.1365
# Epoch 45/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1349 - mean_squared_error: 0.1311
# Epoch 46/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1417 - mean_squared_error: 0.1379
# Epoch 47/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1377 - mean_squared_error: 0.1339
# Epoch 48/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1369 - mean_squared_error: 0.1331
# Epoch 49/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1338 - mean_squared_error: 0.1300
# Epoch 50/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1370 - mean_squared_error: 0.1332
# Epoch 51/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1368 - mean_squared_error: 0.1330
# Epoch 52/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1339 - mean_squared_error: 0.1301
# Epoch 53/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1319 - mean_squared_error: 0.1280
# Epoch 54/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.1295 - mean_squared_error: 0.1257
# Epoch 55/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1358 - mean_squared_error: 0.1320
# Epoch 56/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1274 - mean_squared_error: 0.1236
# Epoch 57/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1319 - mean_squared_error: 0.1281
# Epoch 58/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1291 - mean_squared_error: 0.1253
# Epoch 59/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1304 - mean_squared_error: 0.1266
# Epoch 60/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1283 - mean_squared_error: 0.1245
# Epoch 61/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.1283 - mean_squared_error: 0.1245
# Epoch 62/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1253 - mean_squared_error: 0.1215
# Epoch 63/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.1234 - mean_squared_error: 0.1196
# Epoch 64/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1246 - mean_squared_error: 0.1208
# Epoch 65/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1225 - mean_squared_error: 0.1186
# Epoch 66/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1236 - mean_squared_error: 0.1198
# Epoch 67/2500
# 4/4 [==============================] - 0s 85ms/sample - loss: 0.1197 - mean_squared_error: 0.1159
# Epoch 68/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.1193 - mean_squared_error: 0.1155
# Epoch 69/2500
# 4/4 [==============================] - 0s 85ms/sample - loss: 0.1245 - mean_squared_error: 0.1207
# Epoch 70/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1220 - mean_squared_error: 0.1182
# Epoch 71/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1213 - mean_squared_error: 0.1175
# Epoch 72/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1183 - mean_squared_error: 0.1145
# Epoch 73/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1184 - mean_squared_error: 0.1146
# Epoch 74/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1237 - mean_squared_error: 0.1199
# Epoch 75/2500
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.1173 - mean_squared_error: 0.1135
# Epoch 76/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1191 - mean_squared_error: 0.1153
# Epoch 77/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1182 - mean_squared_error: 0.1144
# Epoch 78/2500
# 4/4 [==============================] - 0s 85ms/sample - loss: 0.1222 - mean_squared_error: 0.1184
# Epoch 79/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.1186 - mean_squared_error: 0.1148
# Epoch 80/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1161 - mean_squared_error: 0.1123
# Epoch 81/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1194 - mean_squared_error: 0.1156
# Epoch 82/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1179 - mean_squared_error: 0.1141
# Epoch 83/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1173 - mean_squared_error: 0.1135
# Epoch 84/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1177 - mean_squared_error: 0.1139
# Epoch 85/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1164 - mean_squared_error: 0.1126
# Epoch 86/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1177 - mean_squared_error: 0.1139
# Epoch 87/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1130 - mean_squared_error: 0.1092
# Epoch 88/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1145 - mean_squared_error: 0.1107
# Epoch 89/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1195 - mean_squared_error: 0.1157
# Epoch 90/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1119 - mean_squared_error: 0.1081
# Epoch 91/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1164 - mean_squared_error: 0.1126
# Epoch 92/2500
# 4/4 [==============================] - 0s 85ms/sample - loss: 0.1141 - mean_squared_error: 0.1103
# Epoch 93/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1136 - mean_squared_error: 0.1098
# Epoch 94/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.1110 - mean_squared_error: 0.1072
# Epoch 95/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.1157 - mean_squared_error: 0.1120
# Epoch 96/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1110 - mean_squared_error: 0.1072
# Epoch 97/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1141 - mean_squared_error: 0.1103
# Epoch 98/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1085 - mean_squared_error: 0.1047
# Epoch 99/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1095 - mean_squared_error: 0.1057
# Epoch 100/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1126 - mean_squared_error: 0.1088
# Epoch 101/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1086 - mean_squared_error: 0.1049
# Epoch 102/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1082 - mean_squared_error: 0.1044
# Epoch 103/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1110 - mean_squared_error: 0.1072
# Epoch 104/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1086 - mean_squared_error: 0.1049
# Epoch 105/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1105 - mean_squared_error: 0.1067
# Epoch 106/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1100 - mean_squared_error: 0.1062
# Epoch 107/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1123 - mean_squared_error: 0.1086
# Epoch 108/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1125 - mean_squared_error: 0.1087
# Epoch 109/2500
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1042 - mean_squared_error: 0.1005
# Epoch 110/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.1056 - mean_squared_error: 0.1018
# Epoch 111/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1125 - mean_squared_error: 0.1087
# Epoch 112/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1058 - mean_squared_error: 0.1020
# Epoch 113/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1060 - mean_squared_error: 0.1023
# Epoch 114/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1063 - mean_squared_error: 0.1025
# Epoch 115/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1089 - mean_squared_error: 0.1052
# Epoch 116/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1056 - mean_squared_error: 0.1018
# Epoch 117/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1080 - mean_squared_error: 0.1042
# Epoch 118/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1053 - mean_squared_error: 0.1016
# Epoch 119/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1073 - mean_squared_error: 0.1036
# Epoch 120/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1031 - mean_squared_error: 0.0993
# Epoch 121/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1072 - mean_squared_error: 0.1034
# Epoch 122/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1050 - mean_squared_error: 0.1013
# Epoch 123/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1019 - mean_squared_error: 0.0982
# Epoch 124/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1107 - mean_squared_error: 0.1070
# Epoch 125/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1012 - mean_squared_error: 0.0974
# Epoch 126/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1019 - mean_squared_error: 0.0981
# Epoch 127/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.1028 - mean_squared_error: 0.0991
# Epoch 128/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.1031 - mean_squared_error: 0.0993
# Epoch 129/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0987 - mean_squared_error: 0.0949
# Epoch 130/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1046 - mean_squared_error: 0.1009
# Epoch 131/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1048 - mean_squared_error: 0.1010
# Epoch 132/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1027 - mean_squared_error: 0.0989
# Epoch 133/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0992 - mean_squared_error: 0.0954
# Epoch 134/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1052 - mean_squared_error: 0.1014
# Epoch 135/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1047 - mean_squared_error: 0.1009
# Epoch 136/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1041 - mean_squared_error: 0.1004
# Epoch 137/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1026 - mean_squared_error: 0.0988
# Epoch 138/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1003 - mean_squared_error: 0.0966
# Epoch 139/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1036 - mean_squared_error: 0.0998
# Epoch 140/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0974 - mean_squared_error: 0.0937
# Epoch 141/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0992 - mean_squared_error: 0.0955
# Epoch 142/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.1025 - mean_squared_error: 0.0988
# Epoch 143/2500
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.1018 - mean_squared_error: 0.0981
# Epoch 144/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0988 - mean_squared_error: 0.0950
# Epoch 145/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0990 - mean_squared_error: 0.0953
# Epoch 146/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0983 - mean_squared_error: 0.0946
# Epoch 147/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0982 - mean_squared_error: 0.0945
# Epoch 148/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.1000 - mean_squared_error: 0.0963
# Epoch 149/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0969 - mean_squared_error: 0.0932
# Epoch 150/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1001 - mean_squared_error: 0.0964
# Epoch 151/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0992 - mean_squared_error: 0.0954
# Epoch 152/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0939 - mean_squared_error: 0.0902
# Epoch 153/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0951 - mean_squared_error: 0.0914
# Epoch 154/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.1012 - mean_squared_error: 0.0974
# Epoch 155/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0980 - mean_squared_error: 0.0943
# Epoch 156/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0964 - mean_squared_error: 0.0926
# Epoch 157/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0940 - mean_squared_error: 0.0903
# Epoch 158/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0954 - mean_squared_error: 0.0917
# Epoch 159/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0959 - mean_squared_error: 0.0922
# Epoch 160/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.1002 - mean_squared_error: 0.0965
# Epoch 161/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0970 - mean_squared_error: 0.0933
# Epoch 162/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0947 - mean_squared_error: 0.0909
# Epoch 163/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0982 - mean_squared_error: 0.0944
# Epoch 164/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0948 - mean_squared_error: 0.0911
# Epoch 165/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0951 - mean_squared_error: 0.0914
# Epoch 166/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0916 - mean_squared_error: 0.0879
# Epoch 167/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0924 - mean_squared_error: 0.0887
# Epoch 168/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0961 - mean_squared_error: 0.0924
# Epoch 169/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0937 - mean_squared_error: 0.0900
# Epoch 170/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0970 - mean_squared_error: 0.0933
# Epoch 171/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0924 - mean_squared_error: 0.0886
# Epoch 172/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0926 - mean_squared_error: 0.0889
# Epoch 173/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0948 - mean_squared_error: 0.0911
# Epoch 174/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0932 - mean_squared_error: 0.0895
# Epoch 175/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0926 - mean_squared_error: 0.0889
# Epoch 176/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0900 - mean_squared_error: 0.0863
# Epoch 177/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0930 - mean_squared_error: 0.0893
# Epoch 178/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0928 - mean_squared_error: 0.0891
# Epoch 179/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0905 - mean_squared_error: 0.0867
# Epoch 180/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0948 - mean_squared_error: 0.0911
# Epoch 181/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0911 - mean_squared_error: 0.0874
# Epoch 182/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0929 - mean_squared_error: 0.0892
# Epoch 183/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0906 - mean_squared_error: 0.0869
# Epoch 184/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0901 - mean_squared_error: 0.0864
# Epoch 185/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0890 - mean_squared_error: 0.0853
# Epoch 186/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0928 - mean_squared_error: 0.0891
# Epoch 187/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0911 - mean_squared_error: 0.0874
# Epoch 188/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0926 - mean_squared_error: 0.0889
# Epoch 189/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0883 - mean_squared_error: 0.0846
# Epoch 190/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0900 - mean_squared_error: 0.0863
# Epoch 191/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0900 - mean_squared_error: 0.0862
# Epoch 192/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0905 - mean_squared_error: 0.0868
# Epoch 193/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0961 - mean_squared_error: 0.0924
# Epoch 194/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0868 - mean_squared_error: 0.0831
# Epoch 195/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0909 - mean_squared_error: 0.0872
# Epoch 196/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0947 - mean_squared_error: 0.0910
# Epoch 197/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0901 - mean_squared_error: 0.0864
# Epoch 198/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0884 - mean_squared_error: 0.0847
# Epoch 199/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0894 - mean_squared_error: 0.0857
# Epoch 200/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0889 - mean_squared_error: 0.0852
# Epoch 201/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0865 - mean_squared_error: 0.0828
# Epoch 202/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0921 - mean_squared_error: 0.0884
# Epoch 203/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0878 - mean_squared_error: 0.0841
# Epoch 204/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0898 - mean_squared_error: 0.0861
# Epoch 205/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0882 - mean_squared_error: 0.0845
# Epoch 206/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0868 - mean_squared_error: 0.0831
# Epoch 207/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0846 - mean_squared_error: 0.0809
# Epoch 208/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0893 - mean_squared_error: 0.0856
# Epoch 209/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0861 - mean_squared_error: 0.0824
# Epoch 210/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0846 - mean_squared_error: 0.0810
# Epoch 211/2500
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0849 - mean_squared_error: 0.0812
# Epoch 212/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0848 - mean_squared_error: 0.0811
# Epoch 213/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0828 - mean_squared_error: 0.0791
# Epoch 214/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0858 - mean_squared_error: 0.0822
# Epoch 215/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0841 - mean_squared_error: 0.0804
# Epoch 216/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0839 - mean_squared_error: 0.0803
# Epoch 217/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0886 - mean_squared_error: 0.0849
# Epoch 218/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0868 - mean_squared_error: 0.0831
# Epoch 219/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0849 - mean_squared_error: 0.0812
# Epoch 220/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0866 - mean_squared_error: 0.0829
# Epoch 221/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0829 - mean_squared_error: 0.0793
# Epoch 222/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0832 - mean_squared_error: 0.0795
# Epoch 223/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0835 - mean_squared_error: 0.0799
# Epoch 224/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0808 - mean_squared_error: 0.0771
# Epoch 225/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0877 - mean_squared_error: 0.0840
# Epoch 226/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0839 - mean_squared_error: 0.0802
# Epoch 227/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0843 - mean_squared_error: 0.0806
# Epoch 228/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0840 - mean_squared_error: 0.0804
# Epoch 229/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0806 - mean_squared_error: 0.0769
# Epoch 230/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0848 - mean_squared_error: 0.0811
# Epoch 231/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0861 - mean_squared_error: 0.0824
# Epoch 232/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0802 - mean_squared_error: 0.0765
# Epoch 233/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0844 - mean_squared_error: 0.0807
# Epoch 234/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0858 - mean_squared_error: 0.0821
# Epoch 235/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0845 - mean_squared_error: 0.0809
# Epoch 236/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0817 - mean_squared_error: 0.0781
# Epoch 237/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0816 - mean_squared_error: 0.0779
# Epoch 238/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0819 - mean_squared_error: 0.0782
# Epoch 239/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0831 - mean_squared_error: 0.0794
# Epoch 240/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0812 - mean_squared_error: 0.0776
# Epoch 241/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0853 - mean_squared_error: 0.0816
# Epoch 242/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0843 - mean_squared_error: 0.0806
# Epoch 243/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0802 - mean_squared_error: 0.0765
# Epoch 244/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0821 - mean_squared_error: 0.0785
# Epoch 245/2500
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0821 - mean_squared_error: 0.0784
# Epoch 246/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0846 - mean_squared_error: 0.0809
# Epoch 247/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0796 - mean_squared_error: 0.0759
# Epoch 248/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0815 - mean_squared_error: 0.0778
# Epoch 249/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0822 - mean_squared_error: 0.0785
# Epoch 250/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0802 - mean_squared_error: 0.0765
# Epoch 251/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0804 - mean_squared_error: 0.0768
# Epoch 252/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0799 - mean_squared_error: 0.0762
# Epoch 253/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0775 - mean_squared_error: 0.0738
# Epoch 254/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0798 - mean_squared_error: 0.0762
# Epoch 255/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0773 - mean_squared_error: 0.0736
# Epoch 256/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0801 - mean_squared_error: 0.0764
# Epoch 257/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0793 - mean_squared_error: 0.0757
# Epoch 258/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0798 - mean_squared_error: 0.0761
# Epoch 259/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0796 - mean_squared_error: 0.0759
# Epoch 260/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0779 - mean_squared_error: 0.0742
# Epoch 261/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0797 - mean_squared_error: 0.0760
# Epoch 262/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0796 - mean_squared_error: 0.0759
# Epoch 263/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0790 - mean_squared_error: 0.0754
# Epoch 264/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0796 - mean_squared_error: 0.0760
# Epoch 265/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0807 - mean_squared_error: 0.0771
# Epoch 266/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0782 - mean_squared_error: 0.0745
# Epoch 267/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0795 - mean_squared_error: 0.0759
# Epoch 268/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0792 - mean_squared_error: 0.0755
# Epoch 269/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0785 - mean_squared_error: 0.0749
# Epoch 270/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0774 - mean_squared_error: 0.0737
# Epoch 271/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0786 - mean_squared_error: 0.0749
# Epoch 272/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0791 - mean_squared_error: 0.0755
# Epoch 273/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0777 - mean_squared_error: 0.0741
# Epoch 274/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0784 - mean_squared_error: 0.0748
# Epoch 275/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0789 - mean_squared_error: 0.0752
# Epoch 276/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0768 - mean_squared_error: 0.0732
# Epoch 277/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0777 - mean_squared_error: 0.0740
# Epoch 278/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0766 - mean_squared_error: 0.0729
# Epoch 279/2500
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0807 - mean_squared_error: 0.0770
# Epoch 280/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0753 - mean_squared_error: 0.0716
# Epoch 281/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0794 - mean_squared_error: 0.0757
# Epoch 282/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0761 - mean_squared_error: 0.0725
# Epoch 283/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0755 - mean_squared_error: 0.0718
# Epoch 284/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0797 - mean_squared_error: 0.0761
# Epoch 285/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0739 - mean_squared_error: 0.0702
# Epoch 286/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0764 - mean_squared_error: 0.0728
# Epoch 287/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0748 - mean_squared_error: 0.0712
# Epoch 288/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0750 - mean_squared_error: 0.0713
# Epoch 289/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0743 - mean_squared_error: 0.0707
# Epoch 290/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0776 - mean_squared_error: 0.0739
# Epoch 291/2500
# 4/4 [==============================] - 0s 85ms/sample - loss: 0.0768 - mean_squared_error: 0.0732
# Epoch 292/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0771 - mean_squared_error: 0.0735
# Epoch 293/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0786 - mean_squared_error: 0.0749
# Epoch 294/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0770 - mean_squared_error: 0.0733
# Epoch 295/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0750 - mean_squared_error: 0.0714
# Epoch 296/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0778 - mean_squared_error: 0.0741
# Epoch 297/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0795 - mean_squared_error: 0.0759
# Epoch 298/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0764 - mean_squared_error: 0.0728
# Epoch 299/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0763 - mean_squared_error: 0.0727
# Epoch 300/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0743 - mean_squared_error: 0.0707
# Epoch 301/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0793 - mean_squared_error: 0.0757
# Epoch 302/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0768 - mean_squared_error: 0.0731
# Epoch 303/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0756 - mean_squared_error: 0.0719
# Epoch 304/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0736 - mean_squared_error: 0.0700
# Epoch 305/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0747 - mean_squared_error: 0.0711
# Epoch 306/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0736 - mean_squared_error: 0.0700
# Epoch 307/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0743 - mean_squared_error: 0.0706
# Epoch 308/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0782 - mean_squared_error: 0.0745
# Epoch 309/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0744 - mean_squared_error: 0.0707
# Epoch 310/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0752 - mean_squared_error: 0.0715
# Epoch 311/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0746 - mean_squared_error: 0.0709
# Epoch 312/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0727 - mean_squared_error: 0.0691
# Epoch 313/2500
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0758 - mean_squared_error: 0.0721
# Epoch 314/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0762 - mean_squared_error: 0.0725
# Epoch 315/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0725 - mean_squared_error: 0.0688
# Epoch 316/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0729 - mean_squared_error: 0.0693
# Epoch 317/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0727 - mean_squared_error: 0.0691
# Epoch 318/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0712 - mean_squared_error: 0.0675
# Epoch 319/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0719 - mean_squared_error: 0.0683
# Epoch 320/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0742 - mean_squared_error: 0.0706
# Epoch 321/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0715 - mean_squared_error: 0.0679
# Epoch 322/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0741 - mean_squared_error: 0.0705
# Epoch 323/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0711 - mean_squared_error: 0.0675
# Epoch 324/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0719 - mean_squared_error: 0.0682
# Epoch 325/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0735 - mean_squared_error: 0.0698
# Epoch 326/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0675 - mean_squared_error: 0.0638
# Epoch 327/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0714 - mean_squared_error: 0.0677
# Epoch 328/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0716 - mean_squared_error: 0.0680
# Epoch 329/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0708 - mean_squared_error: 0.0672
# Epoch 330/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0701 - mean_squared_error: 0.0665
# Epoch 331/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0713 - mean_squared_error: 0.0677
# Epoch 332/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0713 - mean_squared_error: 0.0677
# Epoch 333/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0727 - mean_squared_error: 0.0691
# Epoch 334/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0719 - mean_squared_error: 0.0683
# Epoch 335/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0729 - mean_squared_error: 0.0693
# Epoch 336/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0737 - mean_squared_error: 0.0701
# Epoch 337/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0715 - mean_squared_error: 0.0679
# Epoch 338/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0691 - mean_squared_error: 0.0655
# Epoch 339/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0720 - mean_squared_error: 0.0684
# Epoch 340/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0692 - mean_squared_error: 0.0656
# Epoch 341/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0671 - mean_squared_error: 0.0634
# Epoch 342/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0730 - mean_squared_error: 0.0694
# Epoch 343/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0684 - mean_squared_error: 0.0648
# Epoch 344/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0733 - mean_squared_error: 0.0697
# Epoch 345/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0726 - mean_squared_error: 0.0690
# Epoch 346/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0760 - mean_squared_error: 0.0724
# Epoch 347/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0693 - mean_squared_error: 0.0657
# Epoch 348/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0719 - mean_squared_error: 0.0683
# Epoch 349/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0725 - mean_squared_error: 0.0688
# Epoch 350/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0765 - mean_squared_error: 0.0729
# Epoch 351/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0691 - mean_squared_error: 0.0654
# Epoch 352/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0693 - mean_squared_error: 0.0657
# Epoch 353/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0704 - mean_squared_error: 0.0668
# Epoch 354/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0730 - mean_squared_error: 0.0694
# Epoch 355/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0698 - mean_squared_error: 0.0662
# Epoch 356/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0711 - mean_squared_error: 0.0675
# Epoch 357/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0701 - mean_squared_error: 0.0665
# Epoch 358/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0692 - mean_squared_error: 0.0656
# Epoch 359/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0690 - mean_squared_error: 0.0653
# Epoch 360/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0685 - mean_squared_error: 0.0649
# Epoch 361/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0685 - mean_squared_error: 0.0649
# Epoch 362/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0693 - mean_squared_error: 0.0657
# Epoch 363/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0687 - mean_squared_error: 0.0651
# Epoch 364/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0694 - mean_squared_error: 0.0658
# Epoch 365/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0706 - mean_squared_error: 0.0670
# Epoch 366/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0683 - mean_squared_error: 0.0647
# Epoch 367/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0680 - mean_squared_error: 0.0644
# Epoch 368/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0728 - mean_squared_error: 0.0692
# Epoch 369/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0706 - mean_squared_error: 0.0671
# Epoch 370/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0713 - mean_squared_error: 0.0677
# Epoch 371/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0682 - mean_squared_error: 0.0646
# Epoch 372/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0670 - mean_squared_error: 0.0634
# Epoch 373/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0692 - mean_squared_error: 0.0656
# Epoch 374/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0690 - mean_squared_error: 0.0654
# Epoch 375/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0680 - mean_squared_error: 0.0644
# Epoch 376/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0685 - mean_squared_error: 0.0649
# Epoch 377/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0682 - mean_squared_error: 0.0646
# Epoch 378/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0667 - mean_squared_error: 0.0631
# Epoch 379/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0648 - mean_squared_error: 0.0612
# Epoch 380/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0677 - mean_squared_error: 0.0641
# Epoch 381/2500
# 4/4 [==============================] - 0s 101ms/sample - loss: 0.0688 - mean_squared_error: 0.0652
# Epoch 382/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0669 - mean_squared_error: 0.0633
# Epoch 383/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0661 - mean_squared_error: 0.0625
# Epoch 384/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0666 - mean_squared_error: 0.0630
# Epoch 385/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0665 - mean_squared_error: 0.0629
# Epoch 386/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0659 - mean_squared_error: 0.0623
# Epoch 387/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0658 - mean_squared_error: 0.0622
# Epoch 388/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0639 - mean_squared_error: 0.0603
# Epoch 389/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0662 - mean_squared_error: 0.0627
# Epoch 390/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0666 - mean_squared_error: 0.0630
# Epoch 391/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0641 - mean_squared_error: 0.0605
# Epoch 392/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0664 - mean_squared_error: 0.0628
# Epoch 393/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0653 - mean_squared_error: 0.0618
# Epoch 394/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0657 - mean_squared_error: 0.0621
# Epoch 395/2500
# 4/4 [==============================] - 0s 86ms/sample - loss: 0.0660 - mean_squared_error: 0.0624
# Epoch 396/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0651 - mean_squared_error: 0.0616
# Epoch 397/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0665 - mean_squared_error: 0.0629
# Epoch 398/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0641 - mean_squared_error: 0.0605
# Epoch 399/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0642 - mean_squared_error: 0.0606
# Epoch 400/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0668 - mean_squared_error: 0.0632
# Epoch 401/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0650 - mean_squared_error: 0.0614
# Epoch 402/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0688 - mean_squared_error: 0.0653
# Epoch 403/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0637 - mean_squared_error: 0.0601
# Epoch 404/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0661 - mean_squared_error: 0.0625
# Epoch 405/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0643 - mean_squared_error: 0.0608
# Epoch 406/2500
# 4/4 [==============================] - 0s 85ms/sample - loss: 0.0638 - mean_squared_error: 0.0602
# Epoch 407/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0645 - mean_squared_error: 0.0609
# Epoch 408/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0634 - mean_squared_error: 0.0598
# Epoch 409/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0665 - mean_squared_error: 0.0629
# Epoch 410/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0631 - mean_squared_error: 0.0595
# Epoch 411/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0626 - mean_squared_error: 0.0590
# Epoch 412/2500
# 4/4 [==============================] - 0s 88ms/sample - loss: 0.0630 - mean_squared_error: 0.0594
# Epoch 413/2500
# 4/4 [==============================] - 0s 87ms/sample - loss: 0.0641 - mean_squared_error: 0.0605
# Epoch 414/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0642 - mean_squared_error: 0.0607
# Epoch 415/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0624 - mean_squared_error: 0.0588
# Epoch 416/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0630 - mean_squared_error: 0.0594
# Epoch 417/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0644 - mean_squared_error: 0.0608
# Epoch 418/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0660 - mean_squared_error: 0.0625
# Epoch 419/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0623 - mean_squared_error: 0.0588
# Epoch 420/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0644 - mean_squared_error: 0.0608
# Epoch 421/2500
# 4/4 [==============================] - 0s 91ms/sample - loss: 0.0648 - mean_squared_error: 0.0613
# Epoch 422/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0653 - mean_squared_error: 0.0618
# Epoch 423/2500
# 4/4 [==============================] - 0s 89ms/sample - loss: 0.0686 - mean_squared_error: 0.0650
# Epoch 424/2500
# 4/4 [==============================] - 0s 90ms/sample - loss: 0.0685 - mean_squared_error: 0.0649
# Epoch 425/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0643 - mean_squared_error: 0.0607
# Epoch 426/2500
# ...
# Epoch 2361/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0101 - mean_squared_error: 0.0073
# Epoch 2362/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0102 - mean_squared_error: 0.0074
# Epoch 2363/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0101 - mean_squared_error: 0.0073
# Epoch 2364/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0099 - mean_squared_error: 0.0071
# Epoch 2365/2500
# 4/4 [==============================] - 0s 103ms/sample - loss: 0.0099 - mean_squared_error: 0.0071
# Epoch 2366/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0101 - mean_squared_error: 0.0073
# Epoch 2367/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0101 - mean_squared_error: 0.0073
# Epoch 2368/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0104 - mean_squared_error: 0.0077
# Epoch 2369/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0103 - mean_squared_error: 0.0075
# Epoch 2370/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0101 - mean_squared_error: 0.0073
# Epoch 2371/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0101 - mean_squared_error: 0.0074
# Epoch 2372/2500
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0099 - mean_squared_error: 0.0071
# Epoch 2373/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0098 - mean_squared_error: 0.0070
# Epoch 2374/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0099 - mean_squared_error: 0.0071
# Epoch 2375/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0100 - mean_squared_error: 0.0073
# Epoch 2376/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0099 - mean_squared_error: 0.0071
# Epoch 2377/2500
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0102 - mean_squared_error: 0.0074
# Epoch 2378/2500
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0096 - mean_squared_error: 0.0069
# Epoch 2379/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0101 - mean_squared_error: 0.0073
# Epoch 2380/2500
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0100 - mean_squared_error: 0.0073
# Epoch 2381/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0100 - mean_squared_error: 0.0072
# Epoch 2382/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0101 - mean_squared_error: 0.0074
# Epoch 2383/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0097 - mean_squared_error: 0.0070
# Epoch 2384/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0103 - mean_squared_error: 0.0075
# Epoch 2385/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0103 - mean_squared_error: 0.0075
# Epoch 2386/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0098 - mean_squared_error: 0.0070
# Epoch 2387/2500
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0099 - mean_squared_error: 0.0072
# Epoch 2388/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0100 - mean_squared_error: 0.0073
# Epoch 2389/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0098 - mean_squared_error: 0.0071
# Epoch 2390/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0096 - mean_squared_error: 0.0069
# Epoch 2391/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0099 - mean_squared_error: 0.0071
# Epoch 2392/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0102 - mean_squared_error: 0.0074
# Epoch 2393/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0096 - mean_squared_error: 0.0069
# Epoch 2394/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0098 - mean_squared_error: 0.0071
# Epoch 2395/2500
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0097 - mean_squared_error: 0.0069
# Epoch 2396/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0100 - mean_squared_error: 0.0072
# Epoch 2397/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0092 - mean_squared_error: 0.0065
# Epoch 2398/2500
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0098 - mean_squared_error: 0.0070
# Epoch 2399/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0096 - mean_squared_error: 0.0068
# Epoch 2400/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0101 - mean_squared_error: 0.0073
# Epoch 2401/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0095 - mean_squared_error: 0.0067
# Epoch 2402/2500
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0098 - mean_squared_error: 0.0071
# Epoch 2403/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0098 - mean_squared_error: 0.0071
# Epoch 2404/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0094 - mean_squared_error: 0.0066
# Epoch 2405/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0099 - mean_squared_error: 0.0072
# Epoch 2406/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0099 - mean_squared_error: 0.0071
# Epoch 2407/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0098 - mean_squared_error: 0.0071
# Epoch 2408/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0102 - mean_squared_error: 0.0074
# Epoch 2409/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0095 - mean_squared_error: 0.0067
# Epoch 2410/2500
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0100 - mean_squared_error: 0.0072
# Epoch 2411/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0102 - mean_squared_error: 0.0074
# Epoch 2412/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0101 - mean_squared_error: 0.0073
# Epoch 2413/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0095 - mean_squared_error: 0.0068
# Epoch 2414/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0095 - mean_squared_error: 0.0067
# Epoch 2415/2500
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0102 - mean_squared_error: 0.0075
# Epoch 2416/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2417/2500
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0096 - mean_squared_error: 0.0068
# Epoch 2418/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0097 - mean_squared_error: 0.0069
# Epoch 2419/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0094 - mean_squared_error: 0.0066
# Epoch 2420/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0096 - mean_squared_error: 0.0069
# Epoch 2421/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0094 - mean_squared_error: 0.0067
# Epoch 2422/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0091 - mean_squared_error: 0.0064
# Epoch 2423/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0098 - mean_squared_error: 0.0070
# Epoch 2424/2500
# 4/4 [==============================] - 0s 104ms/sample - loss: 0.0099 - mean_squared_error: 0.0072
# Epoch 2425/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0096 - mean_squared_error: 0.0068
# Epoch 2426/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0097 - mean_squared_error: 0.0070
# Epoch 2427/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0094 - mean_squared_error: 0.0066
# Epoch 2428/2500
# 4/4 [==============================] - 0s 102ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2429/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0094 - mean_squared_error: 0.0067
# Epoch 2430/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0089 - mean_squared_error: 0.0061
# Epoch 2431/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0095 - mean_squared_error: 0.0067
# Epoch 2432/2500
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0092 - mean_squared_error: 0.0065
# Epoch 2433/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0093 - mean_squared_error: 0.0066
# Epoch 2434/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0093 - mean_squared_error: 0.0066
# Epoch 2435/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0095 - mean_squared_error: 0.0067
# Epoch 2436/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0097 - mean_squared_error: 0.0070
# Epoch 2437/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0091 - mean_squared_error: 0.0064
# Epoch 2438/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0098 - mean_squared_error: 0.0071
# Epoch 2439/2500
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0094 - mean_squared_error: 0.0067
# Epoch 2440/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0093 - mean_squared_error: 0.0065
# Epoch 2441/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0096 - mean_squared_error: 0.0069
# Epoch 2442/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0095 - mean_squared_error: 0.0068
# Epoch 2443/2500
# 4/4 [==============================] - 0s 100ms/sample - loss: 0.0093 - mean_squared_error: 0.0066
# Epoch 2444/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0097 - mean_squared_error: 0.0069
# Epoch 2445/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0100 - mean_squared_error: 0.0073
# Epoch 2446/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0089 - mean_squared_error: 0.0061
# Epoch 2447/2500
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2448/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2449/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0100 - mean_squared_error: 0.0072
# Epoch 2450/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0089 - mean_squared_error: 0.0061
# Epoch 2451/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0091 - mean_squared_error: 0.0064
# Epoch 2452/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0097 - mean_squared_error: 0.0069
# Epoch 2453/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0097 - mean_squared_error: 0.0069
# Epoch 2454/2500
# 4/4 [==============================] - 0s 108ms/sample - loss: 0.0088 - mean_squared_error: 0.0060
# Epoch 2455/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0093 - mean_squared_error: 0.0066
# Epoch 2456/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0094 - mean_squared_error: 0.0067
# Epoch 2457/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0092 - mean_squared_error: 0.0065
# Epoch 2458/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0096 - mean_squared_error: 0.0068
# Epoch 2459/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2460/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0090 - mean_squared_error: 0.0062
# Epoch 2461/2500
# 4/4 [==============================] - 0s 109ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2462/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0089 - mean_squared_error: 0.0062
# Epoch 2463/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2464/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0088 - mean_squared_error: 0.0060
# Epoch 2465/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0088 - mean_squared_error: 0.0061
# Epoch 2466/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0092 - mean_squared_error: 0.0064
# Epoch 2467/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0094 - mean_squared_error: 0.0067
# Epoch 2468/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0093 - mean_squared_error: 0.0066
# Epoch 2469/2500
# 4/4 [==============================] - 0s 107ms/sample - loss: 0.0092 - mean_squared_error: 0.0065
# Epoch 2470/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2471/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0092 - mean_squared_error: 0.0065
# Epoch 2472/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0089 - mean_squared_error: 0.0062
# Epoch 2473/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0096 - mean_squared_error: 0.0069
# Epoch 2474/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0089 - mean_squared_error: 0.0062
# Epoch 2475/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0091 - mean_squared_error: 0.0063
# Epoch 2476/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0095 - mean_squared_error: 0.0068
# Epoch 2477/2500
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0091 - mean_squared_error: 0.0064
# Epoch 2478/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0092 - mean_squared_error: 0.0065
# Epoch 2479/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2480/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0091 - mean_squared_error: 0.0064
# Epoch 2481/2500
# 4/4 [==============================] - 0s 99ms/sample - loss: 0.0098 - mean_squared_error: 0.0071
# Epoch 2482/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0089 - mean_squared_error: 0.0062
# Epoch 2483/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0096 - mean_squared_error: 0.0069
# Epoch 2484/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0089 - mean_squared_error: 0.0061
# Epoch 2485/2500
# 4/4 [==============================] - 0s 105ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2486/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0085 - mean_squared_error: 0.0057
# Epoch 2487/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0099 - mean_squared_error: 0.0072
# Epoch 2488/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0092 - mean_squared_error: 0.0065
# Epoch 2489/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0088 - mean_squared_error: 0.0061
# Epoch 2490/2500
# 4/4 [==============================] - 0s 95ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2491/2500
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0092 - mean_squared_error: 0.0064
# Epoch 2492/2500
# 4/4 [==============================] - 0s 98ms/sample - loss: 0.0093 - mean_squared_error: 0.0066
# Epoch 2493/2500
# 4/4 [==============================] - 0s 94ms/sample - loss: 0.0089 - mean_squared_error: 0.0062
# Epoch 2494/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0090 - mean_squared_error: 0.0062
# Epoch 2495/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0093 - mean_squared_error: 0.0066
# Epoch 2496/2500
# 4/4 [==============================] - 0s 96ms/sample - loss: 0.0088 - mean_squared_error: 0.0061
# Epoch 2497/2500
# 4/4 [==============================] - 0s 92ms/sample - loss: 0.0085 - mean_squared_error: 0.0057
# Epoch 2498/2500
# 4/4 [==============================] - 0s 93ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2499/2500
# 4/4 [==============================] - 0s 106ms/sample - loss: 0.0090 - mean_squared_error: 0.0063
# Epoch 2500/2500
# 4/4 [==============================] - 0s 97ms/sample - loss: 0.0085 - mean_squared_error: 0.0057

# %%
# summary stuff
color_list=['b','g','r','c','m','y','k','tab:purple']

def get_pds(activations, start_idx,end_idx):
    # get mean activation from start_idx to end in each direction for each neuron
    mean_activation = np.mean(activations[:,start_idx:end_idx,:],axis=1)
    pds = np.zeros((mean_activation.shape[1],))
    depths = np.zeros((mean_activation.shape[1],))
    # fit mean fr with cosine model
    t=np.array(degs)
    guess_amp = 1; guess_phase = 0; guess_mean = 0;
    for unit in range(mean_activation.shape[1]):
        fit_data = mean_activation[:,unit]
        optimize_fn = lambda x: x[0]*np.cos(t+x[1]) + x[2] - fit_data
        fit = least_squares(optimize_fn,x0=[guess_amp,guess_phase,guess_mean],bounds=([0,-np.pi,-1],[3,np.pi,1]))        
        pds[unit] = fit.x[1]
        depths[unit] = fit.x[0]
        # use theta param as pd
    return pds, depths

def make_activation_grid(activations,cell,args):
    activation_grid = np.zeros((activations.shape[0],activations.shape[1],args.latent_shape[0],args.latent_shape[1]))
    pos_lis = cell.pos.astype("int")
    for i in range(activation_grid.shape[0]):
        for j in range(activation_grid.shape[1]):
            for k in range(pos_lis.shape[0]):
                activation_grid[i,j,pos_lis[k,0],pos_lis[k,1]] = activations[i,j,k]
    
    return activation_grid

        

go_cue_offset = [10,30]
activations = activation_model.predict(x_test)
rnn_activations = activations[1]
y_pred = activations[-1]
pd_data,depth_data = get_pds(rnn_activations,go_cue_offset[0]+go_cue_idx,go_cue_offset[1]+go_cue_idx)
plt.figure()
plt.subplot(2,2,1)
plt.hist(pd_data,20);
plt.subplot(2,2,2)
plt.hist(depth_data,20);
plt.subplot(2,2,3)

pd_grid = np.zeros(args.latent_shape)
pos_lis = cell.pos.astype("int")
for i in range(pd_data.shape[0]):
    pd_grid[pos_lis[i,0],pos_lis[i,1]] = pd_data[i]
plt.imshow(pd_grid)

if(predict_emg==1):
    out_idx = [12,14,16,18]
else:
    out_idx = [0,1]
    
plt.figure()
for i_out in range(len(out_idx)):
    plt.subplot(2,2,i_out+1)
    for tgt_dir_idx in range(y_test.shape[0]):
        plt.plot(np.transpose(y_pred[tgt_dir_idx,:,out_idx[i_out]]),'--',color=color_list[tgt_dir_idx]) 
        plt.plot(np.transpose(y_test[tgt_dir_idx,:,out_idx[i_out]]),'-',color=color_list[tgt_dir_idx])
        
        
rnn_activation_grid = make_activation_grid(rnn_activations,cell,args)
idx_plot = go_cue_idx
plt.figure()
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(rnn_activation_grid[i,idx_plot,:,:])
    
idx_plot = go_cue_idx+15
plt.figure()
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(rnn_activation_grid[i,idx_plot,:,:])
    
idx_plot = go_cue_idx+30
plt.figure()
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(rnn_activation_grid[i,idx_plot,:,:])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# compare activation map vs shuffled maps to see if there is "topography"
num_shuffles = 1000

def shuffle_map(act_map):
    act_map = np.transpose(act_map)
    act_map = np.random.permutation(act_map)
    act_map = np.transpose(act_map)
    return act_map

def get_lateral_loss(act_map):
    A = tf.matmul(tf.convert_to_tensor(act_map,dtype="float32"),cell.lateral_effect)
    # loss is -1*mean of diagonal elements
    return -1*tf.reduce_mean(tf.linalg.diag_part(A))

def evaluate_topography(activations):
    num_steps = activations.shape[1]
    shuffled_loss = np.zeros((num_steps,num_shuffles))
    act_loss = np.zeros((num_steps,))
    act_loss_perc = np.zeros_like(act_loss)
    # for each step in time
    for i_step in range(num_steps):
        # shuffle map some number of times
        activation_map = activations[:,i_step,:]
        act_loss[i_step] = get_lateral_loss(activation_map)
        
        for i_shuffle in range(num_shuffles):
            shuffled_map = shuffle_map(activation_map)
            shuffled_loss[i_step,i_shuffle] = get_lateral_loss(shuffled_map)
        # get percentile of act_loss
        act_loss_perc[i_step] = percentileofscore(shuffled_loss[i_step,:],act_loss[i_step])
        
        
    return act_loss, shuffled_loss, act_loss_perc
        
activations = activation_model.predict(x_test)
rnn_activations = activations[1]    
rnn_activations.shape
act_loss, shuffled_loss, act_loss_perc = evaluate_topography(rnn_activations)
plt.figure()
plt.subplot(2,1,1)
plt.plot(act_loss_perc)
plt.subplot(2,1,2)
plt.plot(y_pred[0,:,0])

# %%
# stimulation experiments    
def mean_squared_difference(x,y):
    # x,y is a tgt x time x signal matrix, get meansquared difference between x,y over time in all tgt conditions across signals
    return np.mean((x-y)**2,axis=2)

def get_recovery_time(msd): # from end of stim
    # threshold is based on msd at end of trial
    threshold = 0.1*np.max(np.max(msd))
    # find first time under threshold post end of stim
    under_threshold = np.argwhere(msd[:,stim_params.stim_time[1]:]<=threshold)
    recov_time = np.zeros((msd.shape[0],),dtype=np.int)
    
    for tgt_idx in range(msd.shape[0]):
        is_tgt = np.nonzero(under_threshold[:,0]==tgt_idx)
        if(len(is_tgt[0])==0):
            recov_time[tgt_idx] = msd.shape[1]-stim_params.stim_time[1]+1
        else:
            recov_time[tgt_idx] = under_threshold[is_tgt[0][0],1]
    return recov_time
   
def get_stim_effect(msd):
    return np.mean(msd[:,stim_params.stim_time[0]:stim_params.stim_time[1]],axis=1)
    
def get_metrics(x,y):
    # get msd
    msd = mean_squared_difference(x,y)
    
    # get recovery time based on msd
    recov_time = get_recovery_time(msd)
    stim_effect = get_stim_effect(msd)
    return (msd,recov_time,stim_effect)


def get_stim_data():
    stim_params.is_stim=False
    cell.reset_counter()
    activations = activation_model.predict(x_test)
    rnn_activations_no_stim = activations[1]
    emg_pred_no_stim = activations[-1]

    stim_params.is_stim=True
    cell.reset_counter()
    activations = activation_model.predict(x_test)
    rnn_activations_stim = activations[1]
    emg_pred_stim = activations[-1]
    
    emg_metrics = get_metrics(emg_pred_no_stim,emg_pred_stim)
    rnn_metrics = get_metrics(rnn_activations_no_stim,rnn_activations_stim)
    #rnn_activation_grid_no_stim = make_activation_grid(rnn_activations_no_stim,cell,args)
    #rnn_activation_grid_stim = make_activation_grid(rnn_activations_stim,cell,args)
    return emg_metrics, rnn_metrics
    
def run_stim_exp():    
    emg_recov = np.zeros((stim_pos_test.shape[0],len(stim_dist_tau_test),len(stim_duration_test),x_test.shape[0]))
    rnn_recov = np.zeros_like(emg_recov)
    emg_stim_effect = np.zeros_like(emg_recov)
    rnn_stim_effect = np.zeros_like(emg_recov)
    
    for i_pos in range(stim_pos_test.shape[0]):
        print(i_pos/stim_pos_test.shape[0])
        stim_params.stim_pos = stim_pos_test[i_pos,:]
        for i_tau in range(len(stim_dist_tau_test)):
            stim_params.stim_dist_tau = stim_dist_tau_test[i_tau]
            for i_dur in range(len(stim_duration_test)):
                stim_params.stim_time = [go_cue_idx+5,go_cue_idx+5+stim_duration_test[i_dur]-1]
                
                emg_metrics, rnn_metrics = get_stim_data()
                emg_recov[i_pos,i_tau,i_dur,:] = emg_metrics[1]
                emg_stim_effect[i_pos,i_tau,i_dur,:] = emg_metrics[2]
                rnn_recov[i_pos,i_tau,i_dur,:] = rnn_metrics[1]
                rnn_stim_effect[i_pos,i_tau,i_dur,:] = rnn_metrics[2]

    
    print("done")
    return emg_recov, emg_stim_effect, rnn_recov, rnn_stim_effect

stim_params = StimParams()
# get stim conditions
x = np.linspace(0, args.latent_shape[0], 5, dtype=np.float32)
y = np.linspace(0, args.latent_shape[1], 5, dtype=np.float32)
xv, yv = np.meshgrid(x, y)
xv = np.reshape(xv, (xv.size, 1))
yv = np.reshape(yv, (yv.size, 1))
stim_pos_test = np.hstack((xv, yv))
stim_dist_tau_test = [0.5,1,2,5,10,20]
stim_duration_test = [1,2,4,8,16]

emg_recov, emg_stim_effect, rnn_recov, rnn_stim_effect=run_stim_exp()

# average over stim positions
emg_recov_mean = np.mean(np.mean(emg_recov,axis=3),axis=0)
emg_stim_effect_mean = np.mean(np.mean(emg_stim_effect,axis=3),axis=0)
rnn_recov_mean = np.mean(np.mean(rnn_recov,axis=3),axis=0)
rnn_stim_effect_mean = np.mean(np.mean(rnn_stim_effect,axis=3),axis=0)

# plot effect of amplitude and stim duration
plt.figure()
ax = plt.axes(projection='3d')
for i_tau in range(len(stim_dist_tau_test)):
    for i_dur in range(len(stim_duration_test)):
        ax.scatter3D(stim_dist_tau_test[i_tau],stim_duration_test[i_dur],rnn_stim_effect_mean[i_tau,i_dur],'.',color='k')
        
ax.set_xlabel("stim tau")
ax.set_ylabel("stim duration")
ax.set_zlabel("stim effect")

# plot recovery with different amplitudes and stim durations
plt.figure()
ax = plt.axes(projection='3d')
for i_tau in range(len(stim_dist_tau_test)):
    for i_dur in range(len(stim_duration_test)):
        ax.scatter3D(stim_dist_tau_test[i_tau],stim_duration_test[i_dur],rnn_recov_mean[i_tau,i_dur],'.',color='k')
        
ax.set_xlabel("stim tau")
ax.set_ylabel("stim duration")
ax.set_zlabel("recovery")

# %%
args.noise_val = 0.0
stim_params.is_stim = True
stim_params.stim_pos = np.array([10,10])
stim_params.stim_dist_tau = 4
stim_params.stim_time = [go_cue_idx+10,go_cue_idx+15]
cell.reset_counter()
activations = activation_model.predict(x_test)
rnn_activations_stim = activations[1]
y_pred_stim = activations[-1]
rnn_activation_grid_stim = make_activation_grid(rnn_activations_stim,cell,args)

stim_params.is_stim=False
cell.reset_counter()
activations = activation_model.predict(x_test)
rnn_activations_no_stim = activations[1]
y_pred_no_stim = activations[-1]
rnn_activation_grid_no_stim = make_activation_grid(rnn_activations_no_stim,cell,args)

rnn_activation_grid_diff = rnn_activation_grid_stim - rnn_activation_grid_no_stim

# plot activation difference
plt.figure()
subplot_idx = [6,2,4,8]
for i in range(len(subplot_idx)):
    plt.subplot(3,3,subplot_idx[i])
    plt.imshow(rnn_activation_grid_diff[i,stim_params.stim_time[0],:,:])
    plt.colorbar()
 

plt.figure()
subplot_idx = [6,2,4,8]
for i in range(len(subplot_idx)):
    plt.subplot(3,3,subplot_idx[i])
    plt.imshow(rnn_activation_grid_diff[i,stim_params.stim_time[1]+1,:,:])
    plt.colorbar()

# plot prediction in both cases
plt.figure()
out_idx = 7
for tgt_dir_idx in range(y_pred_no_stim.shape[0]):
    plt.subplot(3,3,tgt_dir_idx+1)
    plt.plot(y_pred_no_stim[tgt_dir_idx,:,out_idx])
    plt.plot(y_pred_stim[tgt_dir_idx,:,out_idx])
    plt.axvline(stim_params.stim_time[0],linewidth=0.2)
    plt.axvline(stim_params.stim_time[0],linewidth=0.2)
    
# example neuron
plt.figure()
unit=37
for tgt_idx in range(rnn_activations_no_stim.shape[0]):
    plt.subplot(3,3,tgt_idx+1)
    plt.plot(np.transpose(rnn_activations_no_stim[tgt_idx,:,unit]),color=color_list[tgt_idx]);
    plt.plot(np.transpose(rnn_activations_stim[tgt_idx,:,unit]),'--',color=color_list[tgt_idx]);
    plt.axvline(stim_params.stim_time[0],linewidth=0.2)
    plt.axvline(stim_params.stim_time[1],linewidth=0.2)

# %%
def plot_pca_traces(data,tgt_idx,dim_idx,is_stim=False):
    line_type = '-'
    if(is_stim):
        line_type='--'
    plt.plot(data[tgt_idx,:,dim_idx[0]],data[tgt_idx,:,dim_idx[1]],line_type,color=color_list[tgt_idx]);
    plt.plot(data[tgt_idx,0,dim_idx[0]],data[tgt_idx,0,dim_idx[1]],'.',color=color_list[tgt_idx]);
    plt.plot(data[tgt_idx,go_cue_idx,dim_idx[0]],data[tgt_idx,go_cue_idx,dim_idx[1]],'o',color=color_list[tgt_idx])
    
# dynamical analysis (PCA? and such on activations in RNN layer)
# activations is tgt_dir x time x neuron
# truncate activations from go cue to end
rnn_no_stim_trunc = rnn_activations_no_stim[:,:,:]
rnn_stim_trunc = rnn_activations_stim[:,:,:]

rnn_activations_no_stim_flat = rnn_no_stim_trunc.reshape(-1,rnn_activations_no_stim.shape[-1])
rnn_activations_stim_flat = rnn_stim_trunc.reshape(-1,rnn_activations_stim.shape[-1])

pca = PCA(n_components=10)
pca.fit(rnn_activations_no_stim_flat)

rnn_pca_no_stim = pca.transform(rnn_activations_no_stim_flat)
rnn_pca_stim = pca.transform(rnn_activations_stim_flat)
rnn_pca_no_stim = rnn_pca_no_stim.reshape(len(degs),int(rnn_pca_no_stim.shape[0]/len(degs)),rnn_pca_no_stim.shape[1])
rnn_pca_stim = rnn_pca_stim.reshape(len(degs),int(rnn_pca_stim.shape[0]/len(degs)),rnn_pca_stim.shape[1])

dims = [1,2]
plt.figure()
for tgt_idx in range(rnn_pca_no_stim.shape[0]):
    plot_pca_traces(rnn_pca_no_stim,tgt_idx,dims)
    
    
plt.figure()
for tgt_idx in range(rnn_pca_no_stim.shape[0]):
    plt.subplot(3,3,tgt_idx+1)
    plot_pca_traces(rnn_pca_no_stim,tgt_idx,dims)
    plot_pca_traces(rnn_pca_stim,tgt_idx,dims,is_stim=True)

# %%
# dpca
# X = multi dimensional array. [n,t,s,d] where n is neurons, t is time, s is stimulus, d is decision
# labels = optional; list of characters to describe parameter axes ('tsd')
# n_components = Dictionary or integer; if integer use the same number of components in each marginalization,
    #otherwise every (key,value) pair refers to the number of components (value) in a marginalization (key).

def plot_dpca_traces(data,is_stim,label,dim):
    if(is_stim):
        linestyle = '--'
    else:
        linestyle = '-'
    x_data = np.arange(0,data[label].shape[1])
    
    for i_tgt in range(data[label].shape[-1]): # targets are in last dimension
        if(data[label].shape[-1] > 4):
            plt.subplot(3,3,i_tgt+1)
        else:
            plt.subplot(2,2,i_tgt+1)
        plt.plot(x_data,data[label][dim,:,i_tgt],color=color_list[i_tgt],linestyle=linestyle)    
        plt.axvline(stim_params.stim_time[0],linewidth=0.2)
        plt.axvline(stim_params.stim_time[1],linewidth=0.2)
        
X_no_stim = np.transpose(rnn_activations_no_stim,(2,1,0))
X_stim = np.transpose(rnn_activations_stim,(2,1,0))

labels = 'ts'
dpca = dPCA.dPCA(labels)
dpca.protect = ['t']
Z_no_stim = dpca.fit_transform(X_no_stim)
Z_stim = dpca.transform(X_stim)


for i_dim in range(3):
    plt.figure()
    plot_dpca_traces(Z_no_stim,0,'t',i_dim)
    plot_dpca_traces(Z_stim,1,'t',i_dim)
